# %% [markdown]
# Ablation Experiments

# %%
import os
os.environ['TF_USE_LEGACY_KERAS'] = '1'
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from utils.preprocess import process_features, moving_average
from networks.UQ_networks import SNER_network, ER_network, SNGP_network, GP_network
from models.UQ_SNGP import UQ_SNGP
from models.UQ_SNER import UQ_SNER

from evidential_deep_learning.losses import EvidentialRegression as edl_loss
from networks.losses import NLL
import tensorflow as tf
from utils.metrics import DAC,score_function

plt.rcParams['xtick.labelsize'] = 13
plt.rcParams['ytick.labelsize'] = 13


# --- Setup directories ---
root_dir = os.getcwd()
feature_dir = os.path.join(root_dir, 'tf_features_pronostia')
weights_dir = os.path.join(root_dir, 'model_weights')
stat_dir = os.path.join(root_dir, 'statistics')
results = []
# --- Define models (SNER) ---
lambbda = 0.5

sner_05 = UQ_SNER(ER_network, lambbda=lambbda)
sner_05.load_weights(os.path.join(weights_dir, 'PI_SNER_lambda_0.5_weights.keras'))

sner_without_sn = UQ_SNER(ER_network, lambbda=lambbda)
sner_without_sn.load_weights(os.path.join(weights_dir, 'PI_SNER_lambda_0.5_weights.keras'))

sner_without_dynamic_weights = UQ_SNER(SNER_network, lambbda=lambbda)
sner_without_dynamic_weights.load_weights(os.path.join(weights_dir, 'PI_SNER_without_dynamic_weights_lambda_0.5_weights.keras'))

sner_without_pg = ER_network()
sner_without_pg.load_weights(os.path.join(weights_dir, 'SNER_without_physics_guidance_lambda_05_weights.keras'))
sner_without_pg.compile(optimizer='adam', loss=edl_loss)

# --- Define models (SNGP) ---
gamma = 1.0

sngp_1 = UQ_SNGP(SNGP_network, gamma=gamma)
sngp_1.load_weights(os.path.join(weights_dir, 'PI_SNGP_gamma_1_weights.keras'))

sngp_without_sn = UQ_SNGP(GP_network, gamma=gamma)
sngp_without_sn.load_weights(os.path.join(weights_dir, 'PI_SNGP_without_SN_gamma_1_weights.keras'))

sngp_without_dynamic_weights = UQ_SNGP(SNGP_network, gamma=gamma,dynamic_weights=False)
sngp_without_dynamic_weights.load_weights(os.path.join(weights_dir, 'PI_SNGP_without_dynamic_weights_gamma_1_weights.keras'))

sngp_without_pg = SNGP_network()
sngp_without_pg.load_weights(os.path.join(weights_dir, 'SNGP_without_physics_guidance_gamma_1_weights.keras'))
sngp_without_pg.compile(optimizer='adam', loss=NLL)


#define MC models


# --- Define model dictionaries ---
sner_models_dict = {
    "Case 1 (SNER)": sner_without_pg,
    "Case 2 (SNER)": sner_without_dynamic_weights,
    "Case 3 (SNER)": sner_without_sn,
    "Case 4 (SNER)": sner_05
}

sngp_models_dict = {
    "Case 1 (SNGP)": sngp_without_pg,
    "Case 2 (SNGP)": sngp_1,
    "Case 3 (SNGP)": sngp_without_sn,
    "Case 4 (SNGP)": sngp_without_dynamic_weights
}

# Merge all models into a single dictionary
all_models_dict = {**sngp_models_dict, **sner_models_dict}

# --- Load Bearing1_1 data ---
bearing_name = "Bearing1_1"
try:
    df = pd.read_csv(os.path.join(feature_dir, f"{bearing_name}_features.csv"))

    xh = process_features(np.array(df['Horizontal'].apply(eval).tolist()))
    xv = process_features(np.array(df['Vertical'].apply(eval).tolist()))
    vibration_features = np.concatenate((xh, xv), axis=-1)
    t_data = df['Time'].values.reshape(-1, 1)
    T_data = (df['Temperature'].values + 273.15).reshape(-1, 1)
    X = np.concatenate([vibration_features, t_data, T_data], axis=1)
    X = StandardScaler().fit_transform(X)

except Exception as e:
    print(f"Failed to load bearing data: {e}")
    raise

# --- Plot Setup ---
plt.style.use('seaborn-v0_8-deep')
fig, axes = plt.subplots(2, 4, figsize=(20, 8), sharex=True, sharey=True)

# Define subtle but distinct colors
color_aleatoric = 'royalblue'
color_epistemic = 'darkorange'
color_total = 'forestgreen'
colors = ['royalblue', 'crimson', 'forestgreen', 'darkorange', 'mediumpurple', 'magenta', 'teal', 'slategray']

for i, (model_name, model) in enumerate(all_models_dict.items()):
    row = 0 if i < 4 else 1
    col = i % 4
    ax = axes[row, col]

    try:
        x_vals = np.arange(len(X))
        is_sner_model = False

        # --- Unified handling for SNER models ---
        if isinstance(model, UQ_SNER):
            mu, aleatoric, epistemic, total_var = model._predict(X)
            total_var = np.clip(total_var, 0, 1)
            aleatoric = np.clip(aleatoric, 0, 0.5)
            epistemic = np.clip(epistemic, 0, 0.5)
            is_sner_model = True

        elif model is sner_without_pg:
            try:
                mu, aleatoric, epistemic, total_var = model._predict(X)
                total_var = np.clip(total_var, 0, 1)
                aleatoric = np.clip(aleatoric, 0, 1)
                epistemic = np.clip(epistemic, 0, 1)
            except Exception as e:
                pred = model.predict(X)
                mu = pred[:, 0]
                alpha = pred[:, 1]
                beta = pred[:, 2]
                v = pred[:, 3]
                mu = np.clip(mu, 0, 1).flatten()
                aleatoric = np.clip(beta / (alpha - 1),0,1)
                epistemic = np.clip(beta / (v * (alpha - 1)),0,1)
                total_var = aleatoric + epistemic
            is_sner_model = True

        if is_sner_model:
            mu = moving_average(mu)
            std_aleatoric = moving_average(aleatoric)
            std_epistemic = moving_average(epistemic)
            std_total = moving_average(total_var)

            lower_aleatoric = mu - 2.0* std_aleatoric
            upper_aleatoric = mu + 2.0* std_aleatoric

            lower_epistemic = lower_aleatoric - 2.0* std_epistemic
            upper_epistemic = upper_aleatoric + 2.0* std_epistemic

            lower_total = mu - 2.0* std_total
            upper_total = mu + 2.0* std_total

            ax.fill_between(x_vals, lower_total, upper_total,
                            color=colors[i], alpha=0.1, label='±Total σ')
            ax.fill_between(x_vals, lower_epistemic, upper_epistemic,
                            color=color_epistemic, alpha=0.2, label='±Epistemic σ')
            ax.fill_between(x_vals, lower_aleatoric, upper_aleatoric,
                            color=color_aleatoric, alpha=0.3, label='±Aleatoric σ')

        # --- SNGP models ---
        else:
            mu, var = model.predict(X)
            mu = np.clip(mu, 0, 1).flatten()

            if isinstance(var, tf.RaggedTensor):
                var = var.to_tensor()[:, None].numpy().squeeze()
                var = np.mean(var, axis=1)

            std_aleatoric = np.sqrt(np.clip(var, 0, 1))
            lower_aleatoric = mu - std_aleatoric
            upper_aleatoric = mu + std_aleatoric

            ax.fill_between(x_vals, lower_aleatoric, upper_aleatoric,
                         color=colors[i], alpha=0.3, label='±Aleatoric σ')
        
            y_true = df['Degradation'].values


        

        # --- Common Plotting ---
        ax.plot(y_true, label='Degradation', color='black', linestyle='--')
        ax.plot(x_vals, moving_average(mu), label='Estimation', color=colors[i])

        ax.set_title(model_name, fontsize=14, fontweight='bold')
        ax.grid(alpha=0.3)
        if col == 0:
            ax.set_ylabel("Normalized Degradation", fontweight='bold')
        if row == 1:
            ax.set_xlabel("Time")

        #limiting y-axis to [0, 1]
        ax.set_ylim(0, 1.3)

        # De-duplicate legend
        handles, labels = ax.get_legend_handles_labels()
        by_label = dict(zip(labels, handles))
        ax.legend(by_label.values(), by_label.keys(), fontsize=11, loc='upper left')

        results.append({
            'Bearing': bearing_name,
            'Model_type': 'SNER' if is_sner_model else 'SNGP',
            'Model': model_name,
            'MSE': mean_squared_error(y_true, mu),
            'MAE': mean_absolute_error(y_true, mu),
            'Score': score_function(y_true, mu).numpy(),
            })



    except Exception as e:
        print(f"Error in model {model_name}: {e}")

# Final formatting
plt.suptitle("Ablation Experiments", fontsize=16, fontweight='bold')
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# update the csv
results_df = pd.DataFrame(results)
results_df.to_csv(os.path.join(stat_dir, 'Paper05_ablation_results.csv'), index=False)
# Out:
# 2026-06-03 01:28:30.375397: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-06-03 01:28:30.432534: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1780421310.494572   28011 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1780421310.510819   28011 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-06-03 01:28:30.557019: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/ustc15/anaconda3/envs/nac/lib/python3.10/site-packages/google/api_core/_python_version_support.py:263: FutureWarning: You are using a Python version (3.10.16) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# 2026-06-03 01:28:33.794662: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2026-06-03 01:28:33.794707: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:137] retrieving CUDA diagnostic information for host: server-application-intelligence
# 2026-06-03 01:28:33.794714: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:144] hostname: server-application-intelligence
# 2026-06-03 01:28:33.794861: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:168] libcuda reported version is: 530.41.3
# 2026-06-03 01:28:33.794884: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:172] kernel reported version is: 530.41.3
# 2026-06-03 01:28:33.794890: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:259] kernel version seems to match DSO: 530.41.3
# Loaded weights from: /home/ustc15/research/phd_pgnn/model_weights/PI_SNER_lambda_0.5_weights.keras
# Loaded weights from: /home/ustc15/research/phd_pgnn/model_weights/PI_SNER_lambda_0.5_weights.keras
# Loaded weights from: /home/ustc15/research/phd_pgnn/model_weights/PI_SNER_without_dynamic_weights_lambda_0.5_weights.keras
# /home/ustc15/anaconda3/envs/nac/lib/python3.10/site-packages/tf_keras/src/initializers/__init__.py:144: UserWarning: The `keras.initializers.serialize()` API should only be used for objects of type `keras.initializers.Initializer`. Found an instance of type <class 'tensorflow.python.ops.init_ops_v2.RandomUniform'>, which may lead to improper serialization.
#   warnings.warn(
# Loaded weights from: /home/ustc15/research/phd_pgnn/model_weights/PI_SNGP_gamma_1_weights.keras
# Loaded weights from: /home/ustc15/research/phd_pgnn/model_weights/PI_SNGP_without_SN_gamma_1_weights.keras
# Loaded weights from: /home/ustc15/research/phd_pgnn/model_weights/PI_SNGP_without_dynamic_weights_gamma_1_weights.keras
# 449/449 [==============================] - 59s 130ms/step
# 449/449 [==============================] - 1s 3ms/step

# %% [markdown]
# DAC for Ablation

# %%
import os
os.environ['TF_USE_LEGACY_KERAS'] = '1'
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from utils.preprocess import process_features, moving_average
from networks.UQ_networks import SNER_network, ER_network, SNGP_network, GP_network
from models.UQ_SNGP import UQ_SNGP
from models.UQ_SNER import UQ_SNER
from evidential_deep_learning.losses import EvidentialRegression as edl_loss
from networks.losses import NLL
import tensorflow as tf
from utils.metrics import DAC,score_function
from scipy.spatial import ckdtree

# --- Directories ---
feature_dir = 'tf_features_pronostia'
weights_dir = 'model_weights'
stat_dir = 'statistics'


plt.rcParams['xtick.labelsize'] = 13
plt.rcParams['ytick.labelsize'] = 13



# --- Define SNER Models ---
lambbda = 0.5

sner_05 = UQ_SNER(SNER_network, lambbda=lambbda)
sner_05.load_weights(os.path.join(weights_dir, 'PI_SNER_lambda_05_weights.keras'))

sner_without_sn = UQ_SNER(ER_network, lambbda=lambbda)
sner_without_sn.load_weights(os.path.join(weights_dir, 'PI_SNER_without_SN_lambda_05_weights.keras'))

sner_without_dynamic_weights = UQ_SNER(SNER_network, lambbda=lambbda)
sner_without_dynamic_weights.load_weights(os.path.join(weights_dir, 'PI_SNER_without_dynamic_weights_lambda_05_weights.keras'))

sner_without_pg = SNER_network()
sner_without_pg.load_weights(os.path.join(weights_dir, 'SNER_without_physics_guidance_lambda_05_weights.keras'))
sner_without_pg.compile(optimizer='adam', loss=edl_loss)

sner_models_dict = {
    "Case 1 (SNER)": sner_without_pg,
    "Case 2 (SNER)": sner_without_dynamic_weights,
    "Case 3 (SNER)": sner_without_sn,
    "Case 4 (SNER)": sner_05
}

# --- Define SNGP Models ---
gamma = 1.0

sngp_1 = UQ_SNGP(SNGP_network, gamma=gamma)
sngp_1.load_weights(os.path.join(weights_dir, 'PI_SNGP_gamma_1_weights.keras'))

sngp_without_sn = UQ_SNGP(GP_network, gamma=gamma)
sngp_without_sn.load_weights(os.path.join(weights_dir, 'PI_SNGP_without_SN_gamma_1_weights.keras'))

sngp_without_dynamic_weights = UQ_SNGP(SNGP_network, gamma=gamma)
sngp_without_dynamic_weights.load_weights(os.path.join(weights_dir, 'PI_SNGP_without_dynamic_weights_gamma_1_weights.keras'))

sngp_without_pg = SNGP_network()
sngp_without_pg.load_weights(os.path.join(weights_dir, 'SNGP_without_physics_guidance_gamma_1_weights.keras'))
sngp_without_pg.compile(optimizer='adam', loss=NLL)

sngp_models_dict = {
    "Case 1 (SNGP)": sngp_without_pg,
    "Case 2 (SNGP)": sngp_without_dynamic_weights,
    "Case 3 (SNGP)": sngp_without_sn,
    "Case 4 (SNGP)": sngp_1
}

# --- Combine All Models ---
all_models_dict = {**sngp_models_dict, **sner_models_dict}

# --- Load IN-domain Data ---
ind_bearings = ['Bearing1_4', 'Bearing1_5', 'Bearing1_6', 'Bearing1_7']
X_in_list = []

for bearing_name in ind_bearings:
    df = pd.read_csv(f'{feature_dir}/{bearing_name}_features.csv')
    X_h = process_features(np.array(df['Horizontal'].apply(eval).tolist()))
    X_v = process_features(np.array(df['Vertical'].apply(eval).tolist()))
    vib_feat = np.concatenate((X_h, X_v), axis=-1)
    t = df['Time'].values.reshape(-1, 1)
    T = (df['Temperature'].values + 273.15).reshape(-1, 1)
    X = np.concatenate([vib_feat, t, T], axis=1)
    X_in_list.append(X)

X_in_full = np.vstack(X_in_list)

# --- Load Test Data for Bearing1_1 ---
bearing_name = 'Bearing1_1'
df = pd.read_csv(f'{feature_dir}/{bearing_name}_features.csv')
X_h_test = process_features(np.array(df['Horizontal'].apply(eval).tolist()))
X_v_test = process_features(np.array(df['Vertical'].apply(eval).tolist()))
vib_feat_test = np.concatenate((X_h_test, X_v_test), axis=-1)
t_test = df['Time'].values.reshape(-1, 1)
T_test = (df['Temperature'].values + 273.15).reshape(-1, 1)
gt_test = df['Degradation'].values.reshape(-1)
X_test = np.concatenate([vib_feat_test, t_test, T_test], axis=1)

# Sample IN-domain data
idx = np.random.choice(X_in_full.shape[0], size=X_test.shape[0], replace=False)
X_in_sample = X_in_full[idx]

# --- Compute DAC for Each Model ---
results = []

for i, (model_name, model) in enumerate(all_models_dict.items()):
    is_sner_model = False

    if isinstance(model, UQ_SNER):
        mu, aleatoric, epistemic, total_var = model._predict(X_test)
        var = total_var
        is_sner_model = True

    elif model is sner_without_pg:
        pred = model.predict(X_test)
        mu = pred[:, 0]
        alpha = pred[:, 1]
        beta = pred[:, 2]
        v = pred[:, 3]

        mu = np.clip(mu, 0, 1).flatten()
        aleatoric = beta / (alpha - 1)
        epistemic = beta / (v * (alpha - 1))
        var = aleatoric + epistemic
        is_sner_model = True

    # --- SNGP Models ---
    else:
        mu, var = model.predict(X_test)
        mu = np.clip(mu, 0, 1).flatten()

        if isinstance(var, tf.RaggedTensor):
            var = var.to_tensor()[:, None].numpy().squeeze()
            var = np.mean(var, axis=1)

    var = np.clip(var, 0, 1)

    # Compute DAC
    dac_score, _ = DAC(X_test, X_in_sample, sigma=np.sqrt(var), m=100)

    # Store result
    results.append({
        'Bearing': bearing_name,
        'Model_type': 'SNER' if is_sner_model else 'SNGP',
        'Model': model_name,
        'DAC': dac_score
    })


# --- Save Results ---
results_df = pd.DataFrame(results)
results_df.to_csv(f"{stat_dir}/ablation_experiments_DAC.csv", index=False)
print("Saved DAC results for Bearing1_1.")
# Out:
# 2026-05-28 14:09:08.299983: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-28 14:09:08.310697: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1779948548.323308   27813 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1779948548.327127   27813 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-05-28 14:09:08.340045: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/ustc15/anaconda3/envs/nac/lib/python3.10/site-packages/google/api_core/_python_version_support.py:263: FutureWarning: You are using a Python version (3.10.16) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# 2026-05-28 14:09:09.669714: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2026-05-28 14:09:09.669757: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:137] retrieving CUDA diagnostic information for host: server-application-intelligence
# 2026-05-28 14:09:09.669766: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:144] hostname: server-application-intelligence
# 2026-05-28 14:09:09.669869: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:168] libcuda reported version is: 530.41.3
# 2026-05-28 14:09:09.669894: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:172] kernel reported version is: 530.41.3
# 2026-05-28 14:09:09.669901: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:259] kernel version seems to match DSO: 530.41.3
# Loaded weights from: model_weights/PI_SNER_lambda_05_weights.keras
# Loaded weights from: model_weights/PI_SNER_without_SN_lambda_05_weights.keras
# Loaded weights from: model_weights/PI_SNER_without_dynamic_weights_lambda_05_weights.keras
# /home/ustc15/anaconda3/envs/nac/lib/python3.10/site-packages/tf_keras/src/initializers/__init__.py:144: UserWarning: The `keras.initializers.serialize()` API should only be used for objects of type `keras.initializers.Initializer`. Found an instance of type <class 'tensorflow.python.ops.init_ops_v2.RandomUniform'>, which may lead to improper serialization.
#   warnings.warn(
# Loaded weights from: model_weights/PI_SNGP_gamma_1_weights.keras
# Loaded weights from: model_weights/PI_SNGP_without_SN_gamma_1_weights.keras
# Loaded weights from: model_weights/PI_SNGP_without_dynamic_weights_gamma_1_weights.keras
# 449/449 [==============================] - 37s 81ms/step
# 449/449 [==============================] - 1s 2ms/step
# Saved DAC results for Bearing1_1.

# %% [markdown]
# Comparison with Baseline models

# %% [markdown]
# a) SNGP results

# %%
import os
os.environ['TF_USE_LEGACY_KERAS'] = '1'
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import load_model
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from scipy.stats import multivariate_normal
from networks.UQ_networks import SNER_network, ER_network, SNGP_network, GP_network
from models.UQ_SNGP import UQ_SNGP
from models.UQ_SNER import UQ_SNER
from utils.preprocess import process_features, moving_average




# --- DIRECTORIES ---
dir = os.getcwd()
feature_dir = os.path.join(dir, 'tf_features_pronostia')
weights_dir = os.path.join(dir, 'model_weights')
stats_dir = os.path.join(dir, 'statistics')
save_dir = os.path.join(dir, 'bearing_plots')
os.makedirs(save_dir, exist_ok=True)

# --- BEARING GROUPS ---
bearings = {
    '100Hz4kN': [
        {'name': 'Bearing1_1', 'failure': 'Outer', 'data_dist': 'OOD'},
        {'name': 'Bearing1_5', 'failure': 'Inner','data_dist':'IND'},
        
]}

plt.rcParams['xtick.labelsize'] = 13
plt.rcParams['ytick.labelsize'] = 13



def plot_contour(mu_values, var_values, ax,color):
    mu_mean = np.mean(mu_values)
    sigma2_mean = np.mean(var_values)
    cov = np.cov(np.vstack([mu_values, var_values]))
    cov += np.eye(2) * 1e-6

    mu = np.linspace(mu_mean - 1, mu_mean + 1, 200)
    sigma2 = np.linspace(max(1e-6, sigma2_mean - 1), sigma2_mean + 1, 200)
    MU, SIGMA2 = np.meshgrid(mu, sigma2)
    pos = np.dstack((MU, SIGMA2))

    rv = multivariate_normal([mu_mean, sigma2_mean], cov)
    Z = rv.pdf(pos)

    ax.contourf(MU, SIGMA2, Z, levels=10, cmap=color)
    ax.contour(MU, SIGMA2, Z, colors='black', linewidths=0.5)
    ax.set_xlabel(r'$\mu$', fontsize=16, fontweight='bold')
    ax.set_xlim(mu_mean - 1, mu_mean + 1)
    ax.set_ylim(0, 0.01)
    ax.set_ylabel(r'$\sigma^2$', fontsize=16, fontweight='bold')
    ax.grid(True, alpha=0.3)

# --- LOAD MODELS ---
sngp_05 = UQ_SNGP(SNGP_network, gamma=0.5)
sngp_05.load_weights(os.path.join(weights_dir, 'PI_SNGP_gamma_05_weights.keras'))

sngp_1 = UQ_SNGP(SNGP_network, gamma=1.0)
sngp_1.model.load_weights(f'{weights_dir}/PI_SNGP_gamma_1_weights.keras')

sngp_2 = UQ_SNGP(SNGP_network, gamma=2.0)
sngp_2.model.load_weights(f'{weights_dir}/PI_SNGP_gamma_2_weights.keras')

# --- MAIN LOOP ---
# --- MAIN LOOP ---
plt.style.use('seaborn-v0_8-deep')

for condition, bearing_list in bearings.items():
    for bearing in bearing_list:
        try:
            bearing_name = bearing['name']
            failure_type = bearing['failure']
            data_dist = bearing['data_dist']

            df = pd.read_csv(os.path.join(feature_dir, f'{bearing_name}_features.csv'))

            xh = process_features(np.array(df['Horizontal'].apply(eval).tolist()))
            xv = process_features(np.array(df['Vertical'].apply(eval).tolist()))
            vibration_features = np.concatenate((xh, xv), axis=-1)
            t_data = np.array(df['Time'].values).reshape(-1, 1)
            T_data = np.array(df['Temperature'].values + 273.15).reshape(-1, 1)
            X = np.concatenate([vibration_features, t_data, T_data], axis=1)

            scaler = StandardScaler()
            X = scaler.fit_transform(X)

            y_true = np.array(df['Degradation'].values)

            # Predict from all three models
            sngp_05_mu, sngp_05_var = sngp_05.predict(X)
            sngp_1_mu, sngp_1_var = sngp_1.predict(X)
            sngp_2_mu, sngp_2_var = sngp_2.predict(X)

            sngp_05_mu = np.clip(sngp_05_mu, 0, 1)
            sngp_05_var = np.clip(sngp_05_var, 0, 1)
            sngp_1_mu = np.clip(sngp_1_mu, 0, 1)
            sngp_1_var = np.clip(sngp_1_var, 0, 1)
            sngp_2_mu = np.clip(sngp_2_mu, 0, 1)
            sngp_2_var = np.clip(sngp_2_var, 0, 1)

            sngp_05_var = moving_average(sngp_05_var)
            sngp_1_var = moving_average(sngp_1_var)
            sngp_2_var = moving_average(sngp_2_var)

            ma_05 = moving_average(sngp_05_mu)
            ma_1 = moving_average(sngp_1_mu)
            ma_2 = moving_average(sngp_2_mu)

            std_05 = np.sqrt(sngp_05_var)
            std_1 = np.sqrt(sngp_1_var)
            std_2 = np.sqrt(sngp_2_var)

            

            # --- PLOTTING ---
            fig, ax = plt.subplots(1, 6, figsize=(30, 6))
            fig.suptitle(rf"{bearing_name} $\in \mathcal{{X}}_{{{data_dist}}}$ ({failure_type})", fontsize=14)
            x_vals = np.arange(len(y_true))

            # γ = 0.5 prediction
            ax[0].plot(y_true, label='Physics-based Degradation', linestyle='--', color='black')
            ax[0].plot(ma_05, label='Estimated μ', color='red')
            ax[0].fill_between(x_vals, sngp_05_mu - 2*std_05, sngp_05_mu + 2*std_05, color='red', alpha=0.2, label=r'±Aleatoric 2σ')
            ax[0].set_title("PC-SNGP(γ=0.5)", fontsize=16, fontweight='bold')
            ax[0].set_xlabel('Time')
            ax[0].set_ylabel(f"Normalized Degradation", fontsize=14, fontweight='bold')
            ax[0].legend(loc='upper left', fontsize=14)
            ax[0].grid(True, alpha=0.3)

            # γ = 0.5 posterior
            plot_contour(sngp_05_mu, sngp_05_var, ax[1],color='Reds')
            ax[1].set_title(r"$p(\mu,\sigma^2)\ \gamma=0.5$", fontsize=16, fontweight='bold')

            # γ = 1.0 prediction
            ax[2].plot(y_true, label='Physics-based Degradation', linestyle='--', color='black')
            ax[2].plot(ma_1, label='Estimated μ', color='blue')
            ax[2].fill_between(x_vals, sngp_1_mu - 2*std_1, sngp_1_mu + 2*std_1, color='blue', alpha=0.2, label=r'±Aleatoric 2σ')
            ax[2].set_title("PC-SNGP(γ=1.0)", fontsize=16, fontweight='bold')
            ax[2].set_xlabel('Time')
            ax[2].legend(loc='upper left', fontsize=14)
            ax[2].grid(True, alpha=0.3)

            # γ = 1.0 posterior
            plot_contour(sngp_1_mu, sngp_1_var, ax[3],color='Blues')
            ax[3].set_title(r"$p(\mu,\sigma^2)\ \gamma=1.0$", fontsize=12, fontweight='bold')

            # γ = 2.0 prediction
            ax[4].plot(y_true, label='Physics-based Degradation', linestyle='--', color='black')
            ax[4].plot(ma_2, label='Estimated μ', color='green')
            ax[4].fill_between(x_vals, sngp_2_mu - 2*std_2, sngp_2_mu + 2*std_2, color='green', alpha=0.1, label=r'±Aleatoric 2σ')
            ax[4].set_title("PC-SNGP(γ=2.0)", fontsize=16, fontweight='bold')
            ax[4].set_xlabel('Time')
            ax[4].legend(loc='upper left', fontsize=14)
            ax[4].grid(True, alpha=0.3)

            # γ = 2.0 posterior
            plot_contour(sngp_2_mu, sngp_2_var, ax[5],color='Greens')
            ax[5].set_title(r"$p(\mu,\sigma^2)\ \gamma=2.0$", fontsize=16, fontweight='bold')

            fig.tight_layout(rect=[0, 0, 1, 0.95])
            plt.show()
            fig.savefig(os.path.join(save_dir, f'SNGP_{bearing_name}.png'),dpi=600)
            plt.close(fig)

        except Exception as e:
            print(f"Error processing {bearing_name}: {e}")
# Out:
# /home/ustc15/anaconda3/envs/tf/lib/python3.10/site-packages/tf_keras/src/initializers/__init__.py:144: UserWarning: The `keras.initializers.serialize()` API should only be used for objects of type `keras.initializers.Initializer`. Found an instance of type <class 'tensorflow.python.ops.init_ops_v2.RandomUniform'>, which may lead to improper serialization.
#   warnings.warn(
# Loaded weights from: /home/ustc15/research/phd_pgnn/model_weights/PI_SNGP_gamma_05_weights.keras

# %%
import os
os.environ['TF_USE_LEGACY_KERAS'] = '1'
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import load_model
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from scipy.stats import multivariate_normal
from networks.UQ_networks import SNER_network, ER_network, SNGP_network, GP_network
from models.UQ_SNGP import UQ_SNGP
from models.UQ_SNER import UQ_SNER
from utils.preprocess import process_features, moving_average


plt.rcParams['xtick.labelsize'] = 13
plt.rcParams['ytick.labelsize'] = 13


# --- DIRECTORIES ---
dir = os.getcwd()
feature_dir = os.path.join(dir, 'tf_features_pronostia')
weights_dir = os.path.join(dir, 'model_weights')
stats_dir = os.path.join(dir, 'statistics')
save_dir = os.path.join(dir, 'bearing_plots')
os.makedirs(save_dir, exist_ok=True)

# --- BEARING GROUPS ---
bearings = {
    '100Hz4kN': [
        {'name': 'Bearing1_1', 'failure': 'Outer', 'data_dist': 'OOD'},
        {'name': 'Bearing1_5', 'failure': 'Inner','data_dist':'IND'},
        
]}


def plot_contour(mu_values, var_values, ax,color):
    mu_mean = np.mean(mu_values)
    sigma2_mean = np.mean(var_values)
    cov = np.cov(np.vstack([mu_values, var_values]))
    cov += np.eye(2) * 1e-6

    mu = np.linspace(mu_mean - 1, mu_mean + 1, 200)
    sigma2 = np.linspace(max(1e-6, sigma2_mean - 1), sigma2_mean + 1, 200)
    MU, SIGMA2 = np.meshgrid(mu, sigma2)
    pos = np.dstack((MU, SIGMA2))

    rv = multivariate_normal([mu_mean, sigma2_mean], cov)
    Z = rv.pdf(pos)

    ax.contourf(MU, SIGMA2, Z, levels=10, cmap=color)
    ax.contour(MU, SIGMA2, Z, colors='black', linewidths=0.5)
    ax.set_xlabel(r'$\mu$')
    ax.set_xlim(mu_mean - 1, mu_mean + 1)
    ax.set_ylim(0, 0.3)
    ax.set_xlim(-0.5, 0.5)
    ax.set_ylabel(r'$\sigma^2$')
    ax.grid(True, alpha=0.3)

# --- LOAD MODELS ---
sner_02 = UQ_SNER(SNER_network, lambbda=0.2)
sner_02.load_weights(os.path.join(weights_dir, 'PI_SNER_lambda_0.2_weights.keras'))

sner_05 = UQ_SNER(SNER_network, lambbda=0.5)
sner_05.load_weights(os.path.join(weights_dir, 'PI_SNER_lambda_0.5_weights.keras'))

sner_1 = UQ_SNER(SNER_network, lambbda=1.0)
sner_1.load_weights(os.path.join(weights_dir, 'PI_SNER_lambda_1_weights.keras'))

# --- MAIN LOOP ---
# --- MAIN LOOP ---

color_aleatoric = 'royalblue'
color_epistemic = 'darkorange'
plt.style.use('seaborn-v0_8-deep')

for condition, bearing_list in bearings.items():
    for bearing in bearing_list:
        try:
            bearing_name = bearing['name']
            failure_type = bearing['failure']
            data_dist = bearing['data_dist']

            df = pd.read_csv(os.path.join(feature_dir, f'{bearing_name}_features.csv'))

            xh = process_features(np.array(df['Horizontal'].apply(eval).tolist()))
            xv = process_features(np.array(df['Vertical'].apply(eval).tolist()))
            vibration_features = np.concatenate((xh, xv), axis=-1)
            t_data = np.array(df['Time'].values).reshape(-1, 1)
            T_data = np.array(df['Temperature'].values + 273.15).reshape(-1, 1)
            X = np.concatenate([vibration_features, t_data, T_data], axis=1)

            scaler = StandardScaler()
            X = scaler.fit_transform(X)

            y_true = np.array(df['Degradation'].values)

            mu_05, aleatoric_05, epistemic_05, total_05 = sner_02._predict(X)
            mu_1, aleatoric_1, epistemic_1, total_1 = sner_05._predict(X)
            mu_2, aleatoric_2, epistemic_2, total_2 = sner_1._predict(X)
            
            mu_05 = np.clip(mu_05, 0, 1)
            total_05 = np.clip(total_05, 0, 1)
            aleatoric_05 = np.clip(aleatoric_05, 0, 0.3)
            epistemic_05 = np.clip(epistemic_05, 0, 0.3)
            mu_1 = np.clip(mu_1, 0, 1)
            total_1 = np.clip(total_1, 0, 0.3)
            aleatoric_1 = np.clip(aleatoric_1, 0, 0.3)
            epistemic_1 = np.clip(epistemic_1, 0, 0.3)
            mu_2 = np.clip(mu_2, 0, 1)
            total_2 = np.clip(total_2, 0, 1)
            aleatoric_2 = np.clip(aleatoric_2, 0, 0.3)
            epistemic_2 = np.clip(epistemic_2, 0, 0.3)

            sngp_05_var = moving_average(total_05)
            sngp_1_var = moving_average(total_1)
            sngp_2_var = moving_average(total_2)

            ma_05 = moving_average(mu_05)
            ma_1 = moving_average(mu_1)
            ma_2 = moving_average(mu_2)

            std_05 = np.sqrt(sngp_05_var)
            std_1 = np.sqrt(sngp_1_var)
            std_2 = np.sqrt(sngp_2_var)

            

            # --- PLOTTING ---
            fig, ax = plt.subplots(1, 6, figsize=(30, 6))
            fig.suptitle(rf"{bearing_name} $\in \mathcal{{X}}_{{{data_dist}}}$ ({failure_type})", fontsize=16)
            x_vals = np.arange(len(y_true))

            # γ = 0.5 prediction
            ax[0].plot(y_true, label='Physics-based Degradation', linestyle='--', color='black')
            ax[0].plot(ma_05, label='Estimated μ', color='red')
            ax[0].fill_between(x_vals, mu_05 - 2*std_05, mu_05 + 2*std_05, color='red', alpha=0.2, label=r'Total 2σ')
            ax[0].fill_between(x_vals, mu_05-2*np.sqrt(aleatoric_05), mu_05+2*np.sqrt(aleatoric_05), color='royalblue', alpha=0.1, label=r'Aleatoric 2σ')
            ax[0].fill_between(x_vals, mu_05-2*np.sqrt(epistemic_05), mu_05+2*np.sqrt(epistemic_05), color='darkorange', alpha=0.1, label=r'Epsitemic 2σ')
            ax[0].set_title(r"PC-SNER($\lambda=0.2$)", fontsize=16, fontweight='bold')
            ax[0].set_xlabel('Time')
            ax[0].set_ylim(0, 1.0)
            ax[0].set_ylabel(f"Normalized Degradation", fontsize=16, fontweight='bold')
            ax[0].legend(loc='upper left', fontsize=14)
            ax[0].grid(True, alpha=0.3)

            # γ = 0.5 posterior
            plot_contour(mu_05, sngp_05_var, ax[1],color='Reds')
            ax[1].set_title(r"$p(\mu,\sigma^2)\ \lambda=0.2$", fontsize=16, fontweight='bold')

            # γ = 1.0 prediction
            ax[2].plot(y_true, label='Physics-based Degradation', linestyle='--', color='black')
            ax[2].plot(ma_1, label='Estimated μ', color='blue')
            ax[2].fill_between(x_vals, mu_1 - 2*std_1, mu_1 + 2*std_1, color='blue', alpha=0.2, label=r'Total 2σ')
            ax[2].fill_between(x_vals, mu_1-2*np.sqrt(aleatoric_1), mu_1+2*np.sqrt(aleatoric_1), color='royalblue', alpha=0.1, label=r'Aleatoric 2σ')
            ax[2].fill_between(x_vals, mu_1-2*np.sqrt(epistemic_1), mu_1+2*np.sqrt(epistemic_1), color='darkorange', alpha=0.1, label=r'Epsitemic 2σ')
            ax[2].set_title(r"PC-SNER($\lambda=0.5$)", fontsize=16, fontweight='bold')
            ax[2].set_xlabel('Time')
            ax[2].set_ylim(0, 1.0)
            ax[2].legend(loc='upper left', fontsize=14)
            ax[2].grid(True, alpha=0.3)

            # γ = 1.0 posterior
            plot_contour(mu_1, sngp_1_var, ax[3],color='Blues')
            ax[3].set_title(r"$p(\mu,\sigma^2)\ \lambda=0.5$", fontsize=16, fontweight='bold')

            # γ = 2.0 prediction
            ax[4].plot(y_true, label='Physics-based Degradation', linestyle='--', color='black')
            ax[4].plot(ma_2, label='Estimated μ', color='green')
            ax[4].fill_between(x_vals, mu_2 - 2*std_2, mu_2 + 2*std_2, color='green', alpha=0.1, label=r'±Total 2σ')
            ax[4].fill_between(x_vals, mu_2-2*np.sqrt(aleatoric_2), mu_2+2*np.sqrt(aleatoric_2), color='royalblue', alpha=0.1, label=r'Aleatoric 2σ')
            ax[4].fill_between(x_vals, mu_2-2*np.sqrt(epistemic_2), mu_2+2*np.sqrt(epistemic_2), color='darkorange', alpha=0.1, label=r'Epsitemic 2σ')
            ax[4].set_title(r"PC-SNER($\lambda=1.0$)", fontsize=16, fontweight='bold')
            ax[4].set_xlabel('Time')
            ax[4].set_ylim(0, 1.0)
            ax[4].legend(loc='upper left', fontsize=14)
            ax[4].grid(True, alpha=0.3)

            # γ = 2.0 posterior
            plot_contour(mu_2, sngp_2_var, ax[5],color='Greens')
            ax[5].set_title(r"$p(\mu,\sigma^2)\ \lambda=1.0$", fontsize=16, fontweight='bold')

            fig.tight_layout(rect=[0, 0, 1, 0.95])
            plt.show()
            fig.savefig(os.path.join(save_dir, f'SNER_{bearing_name}.png'),dpi=600)
            plt.close(fig)

        except Exception as e:
            print(f"Error processing {bearing_name}: {e}")
# Out:
# 2026-06-01 20:53:49.431102: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-06-01 20:53:49.445231: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1780318429.458635   31084 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1780318429.462620   31084 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-06-01 20:53:49.476083: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/ustc15/anaconda3/envs/nac/lib/python3.10/site-packages/google/api_core/_python_version_support.py:263: FutureWarning: You are using a Python version (3.10.16) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# 2026-06-01 20:53:51.445567: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2026-06-01 20:53:51.445601: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:137] retrieving CUDA diagnostic information for host: server-application-intelligence
# 2026-06-01 20:53:51.445605: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:144] hostname: server-application-intelligence
# 2026-06-01 20:53:51.445716: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:168] libcuda reported version is: 530.41.3
# 2026-06-01 20:53:51.445732: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:172] kernel reported version is: 530.41.3
# 2026-06-01 20:53:51.445736: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:259] kernel version seems to match DSO: 530.41.3
# Loaded weights from: /home/ustc15/research/phd_pgnn/model_weights/PI_SNER_lambda_0.2_weights.keras
# Loaded weights from: /home/ustc15/research/phd_pgnn/model_weights/PI_SNER_lambda_0.5_weights.keras
# Loaded weights from: /home/ustc15/research/phd_pgnn/model_weights/PI_SNER_lambda_1_weights.keras

# %%
import os
os.environ['TF_USE_LEGACY_KERAS'] = '1'
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import load_model
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from scipy.stats import multivariate_normal
from networks.UQ_networks import SNER_network, ER_network, SNGP_network, GP_network,mc_network
from models.UQ_SNGP import UQ_SNGP
from models.UQ_SNER import UQ_SNER
from models.UQ_MC import UQ_MC
from utils.preprocess import process_features, moving_average

plt.rcParams['xtick.labelsize'] = 13
plt.rcParams['ytick.labelsize'] = 13



# --- DIRECTORIES ---
dir = os.getcwd()
feature_dir = os.path.join(dir, 'tf_features_pronostia')
weights_dir = os.path.join(dir, 'model_weights')
stats_dir = os.path.join(dir, 'statistics')
save_dir = os.path.join(dir, 'bearing_plots')
os.makedirs(save_dir, exist_ok=True)

# --- BEARING GROUPS ---
bearings = {
    '100Hz4kN': [
        {'name': 'Bearing1_1', 'failure': 'Outer', 'data_dist': 'OOD'},
        {'name': 'Bearing1_5', 'failure': 'Inner','data_dist':'IND'},  
]
}



def plot_contour(mu_values, var_values, ax,color):
    mu_mean = np.mean(mu_values)
    sigma2_mean = np.mean(var_values)
    cov = np.cov(np.vstack([mu_values, var_values]))
    cov += np.eye(2) * 1e-6

    mu = np.linspace(mu_mean - 1, mu_mean + 1, 200)
    sigma2 = np.linspace(max(1e-6, sigma2_mean - 1), sigma2_mean + 1, 200)
    MU, SIGMA2 = np.meshgrid(mu, sigma2)
    pos = np.dstack((MU, SIGMA2))

    rv = multivariate_normal([mu_mean, sigma2_mean], cov)
    Z = rv.pdf(pos)

    ax.contourf(MU, SIGMA2, Z, levels=10, cmap=color)
    ax.contour(MU, SIGMA2, Z, colors='black', linewidths=0.5)
    ax.set_xlabel(r'$\mu$')
    ax.set_ylim(0, 0.02)
    ax.set_xlim(-0.5, 0.5)
    ax.set_ylabel(r'$\sigma^2$')
    ax.grid(True, alpha=0.3)

# --- LOAD MODELS ---

sngp_05 = UQ_MC(mc_network,dropout_rate=0.1)
sngp_05.load_weights(os.path.join(weights_dir, 'PI_MC_dropout_0.1_weights.keras'))

sngp_1 = UQ_MC(mc_network,dropout_rate=0.3)
sngp_1.load_weights(os.path.join(weights_dir, 'PI_MC_dropout_0.3_weights.keras'))

sngp_2 = UQ_MC(mc_network,dropout_rate=0.5)
sngp_2.load_weights(os.path.join(weights_dir, 'PI_MC_dropout_0.5_weights.keras'))



# --- MAIN LOOP ---
# --- MAIN LOOP ---
plt.style.use('seaborn-v0_8-deep')

for condition, bearing_list in bearings.items():
    for bearing in bearing_list:
        try:
            bearing_name = bearing['name']
            failure_type = bearing['failure']
            data_dist = bearing['data_dist']

            df = pd.read_csv(os.path.join(feature_dir, f'{bearing_name}_features.csv'))

            xh = process_features(np.array(df['Horizontal'].apply(eval).tolist()))
            xv = process_features(np.array(df['Vertical'].apply(eval).tolist()))
            vibration_features = np.concatenate((xh, xv), axis=-1)
            t_data = np.array(df['Time'].values).reshape(-1, 1)
            T_data = np.array(df['Temperature'].values + 273.15).reshape(-1, 1)
            X = np.concatenate([vibration_features, t_data, T_data], axis=1)

            scaler = StandardScaler()
            X = scaler.fit_transform(X)

            y_true = np.array(df['Degradation'].values)

            # Predict from all three models
            sngp_05_mu, sngp_05_var = sngp_05._predict(X)
            sngp_1_mu, sngp_1_var = sngp_1._predict(X)
            sngp_2_mu, sngp_2_var = sngp_2._predict(X)

            sngp_05_mu = np.clip(sngp_05_mu, 0, 1)
            sngp_05_var = np.clip(sngp_05_var, 0, 1)
            sngp_1_mu = np.clip(sngp_1_mu, 0, 1)
            sngp_1_var = np.clip(sngp_1_var, 0, 1)
            sngp_2_mu = np.clip(sngp_2_mu, 0, 1)
            sngp_2_var = np.clip(sngp_2_var, 0, 1)

            sngp_05_var = moving_average(sngp_05_var)
            sngp_1_var = moving_average(sngp_1_var)
            sngp_2_var = moving_average(sngp_2_var)

            ma_05 = moving_average(sngp_05_mu)
            ma_1 = moving_average(sngp_1_mu)
            ma_2 = moving_average(sngp_2_mu)

            std_05 = np.sqrt(sngp_05_var)
            std_1 = np.sqrt(sngp_1_var)
            std_2 = np.sqrt(sngp_2_var)

            

            # --- PLOTTING ---
            fig, ax = plt.subplots(1, 6, figsize=(30, 6))
            fig.suptitle(rf"{bearing_name} $\in \mathcal{{X}}_{{{data_dist}}}$ ({failure_type})", fontsize=14)
            x_vals = np.arange(len(y_true))

            # γ = 0.5 prediction
            ax[0].plot(y_true, label='Physics-based Degradation', linestyle='--', color='black')
            ax[0].plot(ma_05, label='Estimated μ', color='red')
            ax[0].fill_between(x_vals, sngp_05_mu - 2*std_05, sngp_05_mu + 2*std_05, color='red', alpha=0.2, label=r'±Epistemic 2σ')
            ax[0].set_title(r"PC-MC($\rho_d=0.1$)", fontsize=16, fontweight='bold')
            ax[0].set_xlabel('Time')
            ax[0].set_ylabel(f"Normalized Degradation", fontsize=14, fontweight='bold')
            ax[0].legend(loc='upper left', fontsize=14)
            ax[0].grid(True, alpha=0.3)

            # γ = 0.5 posterior
            plot_contour(sngp_05_mu, sngp_05_var, ax[1],color='Reds')
            ax[1].set_title(r"$p(\mu,\sigma^2)\ \rho=0.1$", fontsize=16, fontweight='bold')

            # γ = 1.0 prediction
            ax[2].plot(y_true, label='Physics-based Degradation', linestyle='--', color='black')
            ax[2].plot(ma_1, label='Estimated μ', color='blue')
            ax[2].fill_between(x_vals, sngp_1_mu - 2*std_1, sngp_1_mu + 2*std_1, color='blue', alpha=0.2, label=r'±Epsitemic 2σ')
            ax[2].set_title(r"PC-MC($\rho_d=0.3$)", fontsize=16, fontweight='bold')
            ax[2].set_xlabel('Time')
            ax[2].legend(loc='upper left', fontsize=14)
            ax[2].grid(True, alpha=0.3)

            # γ = 1.0 posterior
            plot_contour(sngp_1_mu, sngp_1_var, ax[3],color='Blues')
            ax[3].set_title(r"$p(\mu,\sigma^2)\ \rho_d=0.3$", fontsize=12, fontweight='bold')

            # γ = 2.0 prediction
            ax[4].plot(y_true, label='Physics-based Degradation', linestyle='--', color='black')
            ax[4].plot(ma_2, label='Estimated μ', color='green')
            ax[4].fill_between(x_vals, sngp_2_mu - 2*std_2, sngp_2_mu + 2*std_2, color='green', alpha=0.1, label=r'±Epsitemic 2σ')
            ax[4].set_title(r"PC-MC($\rho_d=0.5$)", fontsize=16, fontweight='bold')
            ax[4].set_xlabel('Time')
            ax[4].legend(loc='upper left', fontsize=14)
            ax[4].grid(True, alpha=0.3)

            # γ = 2.0 posterior
            plot_contour(sngp_2_mu, sngp_2_var, ax[5],color='Greens')
            ax[5].set_title(r"$p(\mu,\sigma^2)\ \rho_d=0.5$", fontsize=16, fontweight='bold')

            fig.tight_layout(rect=[0, 0, 1, 0.95])
            plt.show()
            fig.savefig(os.path.join(save_dir, f'MC{bearing_name}.png'),dpi=600)
            plt.close(fig)

        except Exception as e:
            print(f"Error processing {bearing_name}: {e}")
# Out:
# 2026-05-29 20:57:37.981384: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-29 20:57:37.992052: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1780059458.005042    1028 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1780059458.008953    1028 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-05-29 20:57:38.021928: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/ustc15/anaconda3/envs/nac/lib/python3.10/site-packages/google/api_core/_python_version_support.py:263: FutureWarning: You are using a Python version (3.10.16) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# 2026-05-29 20:57:39.657801: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2026-05-29 20:57:39.657855: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:137] retrieving CUDA diagnostic information for host: server-application-intelligence
# 2026-05-29 20:57:39.657868: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:144] hostname: server-application-intelligence
# 2026-05-29 20:57:39.658019: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:168] libcuda reported version is: 530.41.3
# 2026-05-29 20:57:39.658054: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:172] kernel reported version is: 530.41.3
# 2026-05-29 20:57:39.658064: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:259] kernel version seems to match DSO: 530.41.3
# Loaded weights from: /home/ustc15/research/phd_pgnn/model_weights/PI_MC_dropout_0.1_weights.keras
# Loaded weights from: /home/ustc15/research/phd_pgnn/model_weights/PI_MC_dropout_0.3_weights.keras
# Loaded weights from: /home/ustc15/research/phd_pgnn/model_weights/PI_MC_dropout_0.5_weights.keras

# %%
import os
os.environ['TF_USE_LEGACY_KERAS'] = '1'
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import load_model
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from scipy.stats import multivariate_normal
from networks.UQ_networks import SNER_network, ER_network, SNGP_network, GP_network,mc_network
from models.UQ_SNGP import UQ_SNGP
from models.UQ_SNER import UQ_SNER
from models.UQ_MC import UQ_MC
from models.UQ_DE import UQ_DE
from networks.networks import mlp_network
from utils.preprocess import process_features, moving_average
from utils.metrics import score_function


plt.rcParams['xtick.labelsize'] = 13
plt.rcParams['ytick.labelsize'] = 13


# --- DIRECTORIES ---
dir = os.getcwd()
feature_dir = os.path.join(dir, 'tf_features_pronostia')
weights_dir = os.path.join(dir, 'model_weights')
stats_dir = os.path.join(dir, 'statistics')
save_dir = os.path.join(dir, 'bearing_plots')
os.makedirs(save_dir, exist_ok=True)

# --- BEARING GROUPS ---
bearings = {
    '100Hz4kN': [
        {'name': 'Bearing1_1', 'failure': 'Outer', 'data_dist': 'OOD'},
        {'name': 'Bearing1_4', 'failure': 'Inner','data_dist':'IND'},
    ]
    }



def plot_contour(mu_values, var_values, ax,color):
    mu_mean = np.mean(mu_values)
    sigma2_mean = np.mean(var_values)
    cov = np.cov(np.vstack([mu_values, var_values]))
    cov += np.eye(2) * 1e-6

    mu = np.linspace(mu_mean - 1, mu_mean + 1, 200)
    sigma2 = np.linspace(max(1e-6, sigma2_mean - 1), sigma2_mean + 1, 200)
    MU, SIGMA2 = np.meshgrid(mu, sigma2)
    pos = np.dstack((MU, SIGMA2))

    rv = multivariate_normal([mu_mean, sigma2_mean], cov)
    Z = rv.pdf(pos)

    ax.contourf(MU, SIGMA2, Z, levels=10, cmap=color)
    ax.contour(MU, SIGMA2, Z, colors='black', linewidths=0.5)
    ax.set_xlabel(r'$\mu$')
    ax.set_xlim(mu_mean - 1, mu_mean + 1)
    ax.set_ylabel(r'$\sigma^2$')
    ax.grid(True, alpha=0.3)

# --- LOAD MODELS ---

sngp_05 = UQ_DE(mlp_network)
sngp_05.load_weights(os.path.join(weights_dir, 'PI_Ensemble_10_weights.keras'))

sngp_1 = UQ_DE(mlp_network)
sngp_1.load_weights(os.path.join(weights_dir, 'PI_Ensemble_20_weights.keras'))

sngp_2 = UQ_DE(mlp_network)
sngp_2.load_weights(os.path.join(weights_dir, 'PI_Ensemble_30_weights.keras'))



# --- MAIN LOOP ---
# --- MAIN LOOP ---
plt.style.use('seaborn-v0_8-deep')

for condition, bearing_list in bearings.items():
    for bearing in bearing_list:
        try:
            bearing_name = bearing['name']
            failure_type = bearing['failure']
            data_dist = bearing['data_dist']

            df = pd.read_csv(os.path.join(feature_dir, f'{bearing_name}_features.csv'))

            xh = process_features(np.array(df['Horizontal'].apply(eval).tolist()))
            xv = process_features(np.array(df['Vertical'].apply(eval).tolist()))
            vibration_features = np.concatenate((xh, xv), axis=-1)
            t_data = np.array(df['Time'].values).reshape(-1, 1)
            T_data = np.array(df['Temperature'].values + 273.15).reshape(-1, 1)
            X = np.concatenate([vibration_features, t_data, T_data], axis=1)

            scaler = StandardScaler()
            X = scaler.fit_transform(X)

            y_true = np.array(df['Degradation'].values)

            # Predict from all three models
            sngp_05_mu, sngp_05_var = sngp_05._predict(X,num_models=10)
            sngp_1_mu, sngp_1_var = sngp_1._predict(X,num_models=20)
            sngp_2_mu, sngp_2_var = sngp_2._predict(X,num_models=30)

            sngp_05_mu = np.clip(sngp_05_mu, 0, 1)
            sngp_05_var = np.clip(sngp_05_var, 0, 1)
            sngp_1_mu = np.clip(sngp_1_mu, 0, 1)
            sngp_1_var = np.clip(sngp_1_var, 0, 1)
            sngp_2_mu = np.clip(sngp_2_mu, 0, 1)
            sngp_2_var = np.clip(sngp_2_var, 0, 1)

            sngp_05_var = moving_average(sngp_05_var)
            sngp_1_var = moving_average(sngp_1_var)
            sngp_2_var = moving_average(sngp_2_var)

            ma_05 = moving_average(sngp_05_mu)
            ma_1 = moving_average(sngp_1_mu)
            ma_2 = moving_average(sngp_2_mu)

            std_05 = np.sqrt(sngp_05_var)
            std_1 = np.sqrt(sngp_1_var)
            std_2 = np.sqrt(sngp_2_var)

            

            # --- PLOTTING ---
            fig, ax = plt.subplots(1, 6, figsize=(30, 6))
            fig.suptitle(rf"{bearing_name} $\in \mathcal{{X}}_{{{data_dist}}}$ ({failure_type})", fontsize=14)
            x_vals = np.arange(len(y_true))

            # γ = 0.5 prediction
            ax[0].plot(y_true, label='Physics-based Degradation', linestyle='--', color='black')
            ax[0].plot(ma_05, label='Estimated μ', color='red')
            ax[0].fill_between(x_vals, sngp_05_mu - 2*std_05, sngp_05_mu + 2*std_05, color='red', alpha=0.2, label=r'±Epistemic 2σ')
            ax[0].set_title(r"PC-DE($N_m=10$)", fontsize=16, fontweight='bold')
            ax[0].set_xlabel('Time')
            ax[0].set_ylabel(f"Normalized Degradation", fontsize=14, fontweight='bold')
            ax[0].legend(loc='upper left', fontsize=14)
            ax[0].grid(True, alpha=0.3)

            # γ = 0.5 posterior
            plot_contour(sngp_05_mu, sngp_05_var, ax[1],color='Reds')
            ax[1].set_title(r"$p(\mu,\sigma^2)\ N_m=10$", fontsize=16, fontweight='bold')
            ax[1].set_ylim(0, 0.025)


            # γ = 1.0 prediction
            ax[2].plot(y_true, label='Physics-based Degradation', linestyle='--', color='black')
            ax[2].plot(ma_1, label='Estimated μ', color='blue')
            ax[2].fill_between(x_vals, sngp_1_mu - 2*std_1, sngp_1_mu + 2*std_1, color='blue', alpha=0.2, label=r'±Epsitemic 2σ')
            ax[2].set_title(r"PC-DE($N_m=20$)", fontsize=16, fontweight='bold')
            ax[2].set_xlabel('Time')
            ax[2].legend(loc='upper left', fontsize=14)
            ax[2].grid(True, alpha=0.3)

            # γ = 1.0 posterior
            plot_contour(sngp_1_mu, sngp_1_var, ax[3],color='Blues')
            ax[3].set_title(r"$p(\mu,\sigma^2)\ N_m=20$", fontsize=12, fontweight='bold')
            ax[3].set_ylim(0, 0.025)

            # γ = 2.0 prediction
            ax[4].plot(y_true, label='Physics-based Degradation', linestyle='--', color='black')
            ax[4].plot(ma_2, label='Estimated μ', color='green')
            ax[4].fill_between(x_vals, sngp_2_mu - 2*std_2, sngp_2_mu + 2*std_2, color='green', alpha=0.1, label=r'±Epsitemic 2σ')
            ax[4].set_title(r"PC-DE($N_m=30$)", fontsize=16, fontweight='bold')
            ax[4].set_xlabel('Time')
            ax[4].legend(loc='upper left', fontsize=14)
            ax[4].grid(True, alpha=0.3)

            # γ = 2.0 posterior
            plot_contour(sngp_2_mu, sngp_2_var, ax[5],color='Greens')
            ax[5].set_title(r"$p(\mu,\sigma^2)\ N_m=30$", fontsize=16, fontweight='bold')
            ax[5].set_ylim(0, 0.025)

            fig.tight_layout(rect=[0, 0, 1, 0.95])
            plt.show()
            fig.savefig(os.path.join(save_dir, f'DE{bearing_name}.png'),dpi=600)
            plt.close(fig)

        except Exception as e:
            print(f"Error processing {bearing_name}: {e}")
# Out:
# 2026-05-29 23:29:41.257422: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-29 23:29:41.269626: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1780068581.284255   12646 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1780068581.288755   12646 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-05-29 23:29:41.303951: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/ustc15/anaconda3/envs/nac/lib/python3.10/site-packages/google/api_core/_python_version_support.py:263: FutureWarning: You are using a Python version (3.10.16) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# 2026-05-29 23:29:43.406815: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2026-05-29 23:29:43.406851: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:137] retrieving CUDA diagnostic information for host: server-application-intelligence
# 2026-05-29 23:29:43.406856: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:144] hostname: server-application-intelligence
# 2026-05-29 23:29:43.406988: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:168] libcuda reported version is: 530.41.3
# 2026-05-29 23:29:43.407004: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:172] kernel reported version is: 530.41.3
# 2026-05-29 23:29:43.407008: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:259] kernel version seems to match DSO: 530.41.3
# Loaded weights from: /home/ustc15/research/phd_pgnn/model_weights/PI_Ensemble_10_weights.keras
# Loaded weights from: /home/ustc15/research/phd_pgnn/model_weights/PI_Ensemble_20_weights.keras
# Loaded weights from: /home/ustc15/research/phd_pgnn/model_weights/PI_Ensemble_30_weights.keras

# %% [markdown]
# Metric

# %%
import os
os.environ['TF_USE_LEGACY_KERAS'] = '1'
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

import os
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error, mean_absolute_error
from utils.metrics import score_function
from sklearn.preprocessing import StandardScaler
from utils.preprocess import moving_average
from networks.UQ_networks import SNER_network, ER_network, SNGP_network, GP_network,mc_network
from models.UQ_SNGP import UQ_SNGP
from models.UQ_SNER import UQ_SNER
from models.UQ_MC import UQ_MC
from models.UQ_DE import UQ_DE
from networks.networks import mlp_network
from utils.preprocess import process_features, moving_average
from utils.metrics import score_function

# --- DIRECTORIES ---
dir = os.getcwd()
feature_dir = os.path.join(dir, 'tf_features_pronostia')
weights_dir = os.path.join(dir, 'model_weights')
stats_dir = os.path.join(dir, 'statistics')
os.makedirs(stats_dir, exist_ok=True)


# --- BEARING GROUPS ---
bearings = {
    '100Hz4kN': [
        {'name': 'Bearing1_1', 'failure': 'Outer', 'data_dist': 'OOD'},
        {'name': 'Bearing1_5', 'failure': 'Inner', 'data_dist': 'IND'},
    ]
}

# --- LOAD MODELS WITH METHOD NAME INCLUDED ---
models = [
    ('PC-SNGP', UQ_SNGP(SNGP_network, gamma=0.5), {'param': 'gamma', 'value': 0.5, 'file': 'PI_SNGP_gamma_05_weights.keras', 'method': 'predict'}),
    ('PC-SNGP', UQ_SNGP(SNGP_network, gamma=1.0), {'param': 'gamma', 'value': 1.0, 'file': 'PI_SNGP_gamma_1_weights.keras', 'method': 'predict'}),
    ('PC-SNGP', UQ_SNGP(SNGP_network, gamma=2.0), {'param': 'gamma', 'value': 2.0, 'file': 'PI_SNGP_gamma_2_weights.keras', 'method': 'predict'}),

    ('PC-SNER', UQ_SNER(SNER_network, lambbda=0.2), {'param': 'lambda', 'value': 0.2, 'file': 'PI_SNER_lambda_0.2_weights.keras', 'method': 'predict'}),
    ('PC-SNER', UQ_SNER(SNER_network, lambbda=0.5), {'param': 'lambda', 'value': 0.5, 'file': 'PI_SNER_lambda_0.5_weights.keras', 'method': 'predict'}),
    ('PC-SNER', UQ_SNER(SNER_network, lambbda=1.0), {'param': 'lambda', 'value': 1.0, 'file': 'PI_SNER_lambda_1_weights.keras', 'method': 'predict'}),

    ('PC-MC', UQ_MC(mc_network, dropout_rate=0.1), {'param': 'dropout_rate', 'value': 0.1, 'file': 'PI_MC_dropout_0.1_weights.keras', 'method': '_predict'}),
    ('PC-MC', UQ_MC(mc_network, dropout_rate=0.3), {'param': 'dropout_rate', 'value': 0.3, 'file': 'PI_MC_dropout_0.3_weights.keras', 'method': '_predict'}),
    ('PC-MC', UQ_MC(mc_network, dropout_rate=0.5), {'param': 'dropout_rate', 'value': 0.5, 'file': 'PI_MC_dropout_0.5_weights.keras', 'method': '_predict'}),

    ('PC-DE', UQ_DE(mlp_network), {'param': 'num_models', 'value': 10, 'file': 'PI_Ensemble_10_weights.keras', 'method': '_predict'}),
    ('PC-DE', UQ_DE(mlp_network), {'param': 'num_models', 'value': 20, 'file': 'PI_Ensemble_20_weights.keras', 'method': '_predict'}),
    ('PC-DE', UQ_DE(mlp_network), {'param': 'num_models', 'value': 30, 'file': 'PI_Ensemble_30_weights.keras', 'method': '_predict'}),
]

# --- Load weights ---
for model_name, model, config in models:
    model.load_weights(os.path.join(weights_dir, config['file']))
    config['model'] = model
    config['name'] = model_name

# --- Process each bearing separately ---
for condition, bearing_list in bearings.items():
    for bearing in bearing_list:
        results = []

        bearing_name = bearing['name']
        failure_type = bearing['failure']
        data_dist = bearing['data_dist']

        try:
            # Load and process features
            df = pd.read_csv(os.path.join(feature_dir, f'{bearing_name}_features.csv'))
            xh = process_features(np.array(df['Horizontal'].apply(eval).tolist()))
            xv = process_features(np.array(df['Vertical'].apply(eval).tolist()))
            vibration_features = np.concatenate((xh, xv), axis=-1)
            t_data = np.array(df['Time'].values).reshape(-1, 1)
            T_data = np.array(df['Temperature'].values + 273.15).reshape(-1, 1)
            X = np.concatenate([vibration_features, t_data, T_data], axis=1)

            scaler = StandardScaler()
            X = scaler.fit_transform(X)

            y_true = np.array(df['Degradation'].values)

            # Loop over all models
            for config in models:
                model = config[2]['model']
                model_name = config[2]['name']
                param_name = config[2]['param']
                param_value = config[2]['value']
                method = config[2]['method']

                try:
                    if method == 'predict':
                        mu, var = getattr(model, method)(X)
                    elif method == '_predict':
                        if model_name == 'PC-DE':
                            mu, var = getattr(model, method)(X, num_models=param_value)
                        else:
                            mu, var = getattr(model, method)(X)
                    else:
                        raise ValueError(f"Unknown method '{method}' for {model_name}")
                    
                    y_true = np.array(df['Degradation'].values)
                    mu = np.clip(mu, 0, 1)
                    var = np.clip(var, 0, 1)
                    mu = moving_average(mu)
                    var = moving_average(var)

                    mse = mean_squared_error(y_true, mu)
                    mae = mean_absolute_error(y_true, mu)
                    score = score_function(y_true, mu).numpy()

                    results.append({
                        'Bearing': bearing_name,
                        'Condition': condition,
                        'Model': model_name,
                        param_name: param_value,
                        'MSE': mse,
                        'MAE': mae,
                        'Score': score
                    })

                except Exception as model_err:
                    print(f"[!] Error in {model_name} ({param_value}) on {bearing_name}: {model_err}")

        except Exception as e:
            print(f"[!] Failed processing {bearing_name}: {e}")
            continue

        # Save per-bearing CSV
        df_result = pd.DataFrame(results)
        save_path = os.path.join(stats_dir, f'PG_metrics_{bearing_name}.csv')
        df_result.to_csv(save_path, index=False)
        print(f"[✓] Saved metrics for {bearing_name} → {save_path}")
# Out:
# 2026-05-29 23:42:15.384458: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-29 23:42:15.395260: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1780069335.408124   20500 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1780069335.411942   20500 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-05-29 23:42:15.425222: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/ustc15/anaconda3/envs/nac/lib/python3.10/site-packages/google/api_core/_python_version_support.py:263: FutureWarning: You are using a Python version (3.10.16) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# 2026-05-29 23:42:17.148199: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2026-05-29 23:42:17.148236: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:137] retrieving CUDA diagnostic information for host: server-application-intelligence
# 2026-05-29 23:42:17.148243: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:144] hostname: server-application-intelligence
# 2026-05-29 23:42:17.148372: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:168] libcuda reported version is: 530.41.3
# 2026-05-29 23:42:17.148391: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:172] kernel reported version is: 530.41.3
# 2026-05-29 23:42:17.148396: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:259] kernel version seems to match DSO: 530.41.3
# /home/ustc15/anaconda3/envs/nac/lib/python3.10/site-packages/tf_keras/src/initializers/__init__.py:144: UserWarning: The `keras.initializers.serialize()` API should only be used for objects of type `keras.initializers.Initializer`. Found an instance of type <class 'tensorflow.python.ops.init_ops_v2.RandomUniform'>, which may lead to improper serialization.
#   warnings.warn(
# Loaded weights from: /home/ustc15/research/phd_pgnn/model_weights/PI_SNGP_gamma_05_weights.keras
# Loaded weights from: /home/ustc15/research/phd_pgnn/model_weights/PI_SNGP_gamma_1_weights.keras
# Loaded weights from: /home/ustc15/research/phd_pgnn/model_weights/PI_SNGP_gamma_2_weights.keras
# Loaded weights from: /home/ustc15/research/phd_pgnn/model_weights/PI_SNER_lambda_0.2_weights.keras
# Loaded weights from: /home/ustc15/research/phd_pgnn/model_weights/PI_SNER_lambda_0.5_weights.keras
# Loaded weights from: /home/ustc15/research/phd_pgnn/model_weights/PI_SNER_lambda_1_weights.keras
# Loaded weights from: /home/ustc15/research/phd_pgnn/model_weights/PI_MC_dropout_0.1_weights.keras
# Loaded weights from: /home/ustc15/research/phd_pgnn/model_weights/PI_MC_dropout_0.3_weights.keras
# Loaded weights from: /home/ustc15/research/phd_pgnn/model_weights/PI_MC_dropout_0.5_weights.keras
# Loaded weights from: /home/ustc15/research/phd_pgnn/model_weights/PI_Ensemble_10_weights.keras
# Loaded weights from: /home/ustc15/research/phd_pgnn/model_weights/PI_Ensemble_20_weights.keras
# Loaded weights from: /home/ustc15/research/phd_pgnn/model_weights/PI_Ensemble_30_weights.keras
# [✓] Saved metrics for Bearing1_1 → /home/ustc15/research/phd_pgnn/statistics/PG_metrics_Bearing1_1.csv
# [✓] Saved metrics for Bearing1_5 → /home/ustc15/research/phd_pgnn/statistics/PG_metrics_Bearing1_5.csv

# %% [markdown]
# Cross-Validation test

# %% [markdown]
# PC-SNGP with XJTU

# %%
import os
os.environ['TF_USE_LEGACY_KERAS'] = '1'
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import load_model
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from scipy.stats import multivariate_normal
from networks.UQ_networks import SNER_network, ER_network, SNGP_network, GP_network
from models.UQ_SNGP import UQ_SNGP
from models.UQ_SNER import UQ_SNER
from utils.preprocess import process_features, moving_average




# --- DIRECTORIES ---
dir = os.getcwd()
feature_dir = os.path.join(dir, 'tf_features_xjtu')
weights_dir = os.path.join(dir, 'model_weights')
stats_dir = os.path.join(dir, 'statistics')
save_dir = os.path.join(dir, 'bearing_plots')
os.makedirs(save_dir, exist_ok=True)

# --- BEARING GROUPS ---
bearings = {
    '100Hz4kN': [
        {'name': 'Bearing1_1', 'failure': 'Outer', 'data_dist': 'OOD'},
        
]}

plt.rcParams['xtick.labelsize'] = 13
plt.rcParams['ytick.labelsize'] = 13



def plot_contour(mu_values, var_values, ax,color):
    mu_mean = np.mean(mu_values)
    sigma2_mean = np.mean(var_values)
    cov = np.cov(np.vstack([mu_values, var_values]))
    cov += np.eye(2) * 1e-6

    mu = np.linspace(mu_mean - 1, mu_mean + 1, 200)
    sigma2 = np.linspace(max(1e-6, sigma2_mean - 1), sigma2_mean + 1, 200)
    MU, SIGMA2 = np.meshgrid(mu, sigma2)
    pos = np.dstack((MU, SIGMA2))

    rv = multivariate_normal([mu_mean, sigma2_mean], cov)
    Z = rv.pdf(pos)

    ax.contourf(MU, SIGMA2, Z, levels=10, cmap=color)
    ax.contour(MU, SIGMA2, Z, colors='black', linewidths=0.5)
    ax.set_xlabel(r'$\mu$', fontsize=16, fontweight='bold')
    ax.set_xlim(mu_mean - 1, mu_mean + 1)
    ax.set_ylim(0, 0.01)
    ax.set_ylabel(r'$\sigma^2$', fontsize=16, fontweight='bold')
    ax.grid(True, alpha=0.3)

# --- LOAD MODELS ---

sngp_1 = UQ_SNGP(SNGP_network, gamma=1.0)
sngp_1.model.load_weights(f'{weights_dir}/PI_SNGP_gamma_1_weights.keras')


# --- MAIN LOOP ---
# --- MAIN LOOP ---
plt.style.use('seaborn-v0_8-deep')

for condition, bearing_list in bearings.items():
    for bearing in bearing_list:
        try:
            bearing_name = bearing['name']
            failure_type = bearing['failure']
            data_dist = bearing['data_dist']

            df = pd.read_csv(os.path.join(feature_dir, f'{bearing_name}_features_with_labels.csv'))

            xh = process_features(np.array(df['Horizontal'].apply(eval).tolist()))
            xv = process_features(np.array(df['Vertical'].apply(eval).tolist()))
            vibration_features = np.concatenate((xh, xv), axis=-1)
            t_data = np.array(df['Time'].values).reshape(-1, 1)
            T_data =np.ones_like(t_data) * 293.15
            X = np.concatenate([vibration_features, t_data, T_data], axis=1)

            scaler = StandardScaler()
            X = scaler.fit_transform(X)

            y_true = np.array(df['Degradation'].values)

            # Predict from all three models
            sngp_1_mu, sngp_1_var = sngp_1.predict(X)

            sngp_1_mu = np.clip(sngp_1_mu, 0, 1)
            sngp_1_var = np.clip(sngp_1_var, 0, 1)

            sngp_1_var = moving_average(sngp_1_var)
            ma_1 = moving_average(sngp_1_mu)
            std_1 = np.sqrt(sngp_1_var)

            

            # --- PLOTTING ---
            fig, ax = plt.subplots(1, 6, figsize=(30, 6))
            fig.suptitle(rf"{bearing_name} $\in \mathcal{{X}}_{{{data_dist}}}$ ({failure_type})", fontsize=14)
            x_vals = np.arange(len(y_true))


            # γ = 1.0 prediction
            ax[2].plot(y_true, label='Physics-based Degradation', linestyle='--', color='black')
            ax[2].plot(ma_1, label='Estimated μ', color='blue')
            ax[2].fill_between(x_vals, sngp_1_mu - 2*std_1, sngp_1_mu + 2*std_1, color='blue', alpha=0.2, label=r'±Aleatoric 2σ')
            ax[2].set_title("PC-SNGP(γ=1.0)", fontsize=16, fontweight='bold')
            ax[2].set_xlabel('Time')
            ax[2].legend(loc='upper left', fontsize=14)
            ax[2].grid(True, alpha=0.3)

            # γ = 1.0 posterior
            plot_contour(sngp_1_mu, sngp_1_var, ax[3],color='Blues')
            ax[3].set_title(r"$p(\mu,\sigma^2)\ \gamma=1.0$", fontsize=12, fontweight='bold')


            fig.tight_layout(rect=[0, 0, 1, 0.95])
            plt.show()
            # fig.savefig(os.path.join(save_dir, f'SNGP_{bearing_name}.png'),dpi=600)
            plt.close(fig)

        except Exception as e:
            print(f"Error processing {bearing_name}: {e}")
# Out:
# 2026-05-30 00:38:27.378612: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-30 00:38:27.389625: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1780072707.402704   19140 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1780072707.406678   19140 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-05-30 00:38:27.420009: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/ustc15/anaconda3/envs/nac/lib/python3.10/site-packages/google/api_core/_python_version_support.py:263: FutureWarning: You are using a Python version (3.10.16) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# 2026-05-30 00:38:29.125652: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2026-05-30 00:38:29.125706: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:137] retrieving CUDA diagnostic information for host: server-application-intelligence
# 2026-05-30 00:38:29.125717: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:144] hostname: server-application-intelligence
# 2026-05-30 00:38:29.125843: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:168] libcuda reported version is: 530.41.3
# 2026-05-30 00:38:29.125875: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:172] kernel reported version is: 530.41.3
# 2026-05-30 00:38:29.125883: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:259] kernel version seems to match DSO: 530.41.3
# /home/ustc15/anaconda3/envs/nac/lib/python3.10/site-packages/tf_keras/src/initializers/__init__.py:144: UserWarning: The `keras.initializers.serialize()` API should only be used for objects of type `keras.initializers.Initializer`. Found an instance of type <class 'tensorflow.python.ops.init_ops_v2.RandomUniform'>, which may lead to improper serialization.
#   warnings.warn(

# %%
import os
os.environ['TF_USE_LEGACY_KERAS'] = '1'
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.preprocessing import StandardScaler
from utils.metrics import score_function
from utils.preprocess import moving_average, process_features
from networks.UQ_networks import ER_network, SNGP_network
from models.UQ_SNGP import UQ_SNGP
from models.UQ_SNER import UQ_SNER

# --- DIRECTORIES ---
dir = os.getcwd()
xjtu_feature_dir = os.path.join(dir, 'tf_features_xjtu')
hust_feature_dir = os.path.join(dir, 'tf_features_hust')

weights_dir = os.path.join(dir, 'model_weights')
stats_dir = os.path.join(dir, 'statistics')
os.makedirs(stats_dir, exist_ok=True)

# --- BEARINGS ---
bearings = {
    '100Hz4kN': [
        {'name': 'Bearing1_1', 'failure': 'Outer', 'data_dist': 'OOD'},
        {'name': 'Bearing1', 'failure': 'Outer', 'data_dist': 'OOD'},
    ]
}

# --- LOAD MODELS ---
models = [
    ('PC-SNGP', UQ_SNGP(SNGP_network, gamma=1.0), 
     {'param': 'gamma', 'value': 1.0, 'file': 'PI_SNGP_gamma_1_weights.keras', 'method': 'predict'}),
    ('PC-SNER', UQ_SNER(SNER_network, lambbda=0.5), 
     {'param': 'lambda', 'value': 0.5, 'file': 'PI_SNER_lambda_0.5_weights.keras', 'method': 'predict'}),
]

# Load weights and add model references
for model_name, model, config in models:
    model.load_weights(os.path.join(weights_dir, config['file']))
    config['model'] = model
    config['name'] = model_name

# --- Map bearings to models ---
bearing_model_map = {
    'Bearing1_1': 'PC-SNGP',
    'Bearing1': 'PC-SNER',
}

# --- PROCESS EACH BEARING ---
for condition, bearing_list in bearings.items():
    for bearing in bearing_list:
        bearing_name = bearing['name']
        results = []

        # Select the right model
        model_name_to_use = bearing_model_map.get(bearing_name)
        if not model_name_to_use:
            print(f"[!] No model assigned for {bearing_name}, skipping.")
            continue

        # Get model config
        model_config = next((cfg[2] for cfg in models if cfg[0] == model_name_to_use), None)
        if model_config is None:
            print(f"[!] Model config for {model_name_to_use} not found.")
            continue

        model = model_config['model']
        param_name = model_config['param']
        param_value = model_config['value']
        method = model_config['method']

        # --- Load bearing-specific features ---
        try:
            # Customize loading for each bearing here
            if bearing_name == 'Bearing1':
                df = pd.read_csv(os.path.join(hust_feature_dir, 'Bearing1_features.csv'))
                t_data = np.array(df['Time'].values).reshape(-1, 1)
                T_data = np.array(df['Temperature'].values + 273.15).reshape(-1, 1)
            elif bearing_name == 'Bearing1_1':
                df = pd.read_csv(os.path.join(xjtu_feature_dir, 'Bearing1_1_features_with_labels.csv'))
                t_data = np.array(df['Time'].values).reshape(-1, 1)
                T_data = np.ones_like(t_data) * 293.15

            else:
                print(f"[!] No feature file defined for {bearing_name}, skipping.")
                continue

            # --- Preprocess features ---
            xh = process_features(np.array(df['Horizontal'].apply(eval).tolist()))
            xv = process_features(np.array(df['Vertical'].apply(eval).tolist()))
            vibration_features = np.concatenate((xh, xv), axis=-1)
            X = np.concatenate([vibration_features, t_data, T_data], axis=1)
            X = StandardScaler().fit_transform(X)
            y_true = np.array(df['Degradation'].values)

            # --- Predict ---
            if method == 'predict':
                mu, var = getattr(model, method)(X)
            elif method == '_predict':
                mu, var = getattr(model, method)(X)
            else:
                raise ValueError(f"Unknown method '{method}' for {model_name_to_use}")

            mu = moving_average(np.clip(mu, 0, 1))
            var = moving_average(np.clip(var, 0, 1))

            mse = mean_squared_error(y_true, mu)
            mae = mean_absolute_error(y_true, mu)
            score = score_function(y_true, mu).numpy()

            results.append({
                'Bearing': bearing_name,
                'Condition': condition,
                'Model': model_name_to_use,
                param_name: param_value,
                'MSE': mse,
                'MAE': mae,
                'Score': score
            })

        except Exception as err:
            print(f"[!] Error processing {bearing_name}: {err}")
            continue

        # --- Save results ---
        df_result = pd.DataFrame(results)
        save_path = os.path.join(stats_dir, f'Cross_validation_PG_metrics_{bearing_name}.csv')
        df_result.to_csv(save_path, index=False)
        print(f"[✓] Saved metrics for {bearing_name} → {save_path}")
# Out:
# /home/ustc15/anaconda3/envs/nac/lib/python3.10/site-packages/tf_keras/src/initializers/__init__.py:144: UserWarning: The `keras.initializers.serialize()` API should only be used for objects of type `keras.initializers.Initializer`. Found an instance of type <class 'tensorflow.python.ops.init_ops_v2.RandomUniform'>, which may lead to improper serialization.
#   warnings.warn(
# Loaded weights from: /home/ustc15/research/phd_pgnn/model_weights/PI_SNGP_gamma_1_weights.keras
# Loaded weights from: /home/ustc15/research/phd_pgnn/model_weights/PI_SNER_lambda_0.5_weights.keras
# [✓] Saved metrics for Bearing1_1 → /home/ustc15/research/phd_pgnn/statistics/Cross_validation_PG_metrics_Bearing1_1.csv
# [✓] Saved metrics for Bearing1 → /home/ustc15/research/phd_pgnn/statistics/Cross_validation_PG_metrics_Bearing1.csv

# %% [markdown]
# PC-SNER with HUST

# %%
import os
os.environ['TF_USE_LEGACY_KERAS'] = '1'
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import load_model
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from scipy.stats import multivariate_normal
from networks.UQ_networks import SNER_network, ER_network, SNGP_network, GP_network
from models.UQ_SNGP import UQ_SNGP
from models.UQ_SNER import UQ_SNER
from utils.preprocess import process_features, moving_average


plt.rcParams['xtick.labelsize'] = 13
plt.rcParams['ytick.labelsize'] = 13


# --- DIRECTORIES ---
dir = os.getcwd()
feature_dir = os.path.join(dir, 'tf_features_hust')
weights_dir = os.path.join(dir, 'model_weights')
stats_dir = os.path.join(dir, 'statistics')
save_dir = os.path.join(dir, 'bearing_plots')
os.makedirs(save_dir, exist_ok=True)

# --- BEARING GROUPS ---
bearings = {
    '100Hz4kN': [
        {'name': 'Bearing1', 'failure': 'Outer', 'data_dist': 'Cross-Val'},
        
]}





def plot_contour(mu_values, var_values, ax,color):
    mu_mean = np.mean(mu_values)
    sigma2_mean = np.mean(var_values)
    cov = np.cov(np.vstack([mu_values, var_values]))
    cov += np.eye(2) * 1e-6

    mu = np.linspace(mu_mean - 1, mu_mean + 1, 200)
    sigma2 = np.linspace(max(1e-6, sigma2_mean - 1), sigma2_mean + 1, 200)
    MU, SIGMA2 = np.meshgrid(mu, sigma2)
    pos = np.dstack((MU, SIGMA2))

    rv = multivariate_normal([mu_mean, sigma2_mean], cov)
    Z = rv.pdf(pos)

    ax.contourf(MU, SIGMA2, Z, levels=10, cmap=color)
    ax.contour(MU, SIGMA2, Z, colors='black', linewidths=0.5)
    ax.set_xlabel(r'$\mu$')
    ax.set_xlim(mu_mean - 1, mu_mean + 1)
    ax.set_ylim(0, 0.01)
    ax.set_xlim(-0.5,0.5)
    ax.set_ylabel(r'$\sigma^2$')
    ax.grid(True, alpha=0.3)

# --- LOAD MODELS ---

sner_05 = UQ_SNER(SNER_network, lambbda=0.5)
sner_05.load_weights(os.path.join(weights_dir, 'PI_SNER_lambda_0.5_weights.keras'))

# --- MAIN LOOP ---
# --- MAIN LOOP ---

color_aleatoric = 'royalblue'
color_epistemic = 'darkorange'
plt.style.use('seaborn-v0_8-deep')

for condition, bearing_list in bearings.items():
    for bearing in bearing_list:
        try:
            bearing_name = bearing['name']
            failure_type = bearing['failure']
            data_dist = bearing['data_dist']

            df = pd.read_csv(os.path.join(feature_dir, f'{bearing_name}_features.csv'))

            xh = process_features(np.array(df['Horizontal'].apply(eval).tolist()))
            xv = process_features(np.array(df['Vertical'].apply(eval).tolist()))
            vibration_features = np.concatenate((xh, xv), axis=-1)
            t_data = np.array(df['Time'].values).reshape(-1, 1)
            
            T_data = np.array(df['Temperature'].values + 273.15).reshape(-1, 1)
            X = np.concatenate([vibration_features, t_data, T_data], axis=1)

            scaler = StandardScaler()
            X = scaler.fit_transform(X)

            y_true = np.array(df['Degradation'].values)

            mu_1, aleatoric_1, epistemic_1, total_1 = sner_05._predict(X)

            
            mu_1 = np.clip(mu_1, 0, 1)
            total_1 = np.clip(total_1, 0, 1)
            sngp_1_var = moving_average(total_1)
            ma_1 = moving_average(mu_1)
            std_1 = np.sqrt(sngp_1_var)

            

            # --- PLOTTING ---
            fig, ax = plt.subplots(1, 6, figsize=(30, 6))
            fig.suptitle(rf"{bearing_name} $\in \mathcal{{X}}_{{{data_dist}}}$ ({failure_type})", fontsize=16)
            x_vals = np.arange(len(y_true))

            # γ = 1.0 prediction
            ax[2].plot(y_true, label='Physics-based Degradation', linestyle='--', color='black')
            ax[2].plot(ma_1, label='Estimated μ', color='blue')
            ax[2].fill_between(x_vals, mu_1 - 2*std_1, mu_1 + 2*std_1, color='blue', alpha=0.2, label=r'Total 2σ')
            ax[2].fill_between(x_vals, mu_1-2*np.sqrt(aleatoric_1), mu_1+2*np.sqrt(aleatoric_1), color='royalblue', alpha=0.1, label=r'Aleatoric 2σ')
            ax[2].fill_between(x_vals, mu_1-2*np.sqrt(epistemic_1), mu_1+2*np.sqrt(epistemic_1), color='darkorange', alpha=0.1, label=r'Epsitemic 2σ')
            ax[2].set_title(r"PC-SNER($\lambda=0.5$)", fontsize=16, fontweight='bold')
            ax[2].set_xlabel('Time')
            ax[2].legend(loc='upper left', fontsize=14)
            ax[2].grid(True, alpha=0.3)

            # γ = 1.0 posterior
            plot_contour(mu_1, sngp_1_var, ax[3],color='Blues')
            ax[3].set_title(r"$p(\mu,\sigma^2)\ \lambda=0.5$", fontsize=16, fontweight='bold')


            fig.tight_layout(rect=[0, 0, 1, 0.95])
            plt.show()
            # fig.savefig(os.path.join(save_dir, f'SNER_{bearing_name}.png'),dpi=600)
            plt.close(fig)

        except Exception as e:
            print(f"Error processing {bearing_name}: {e}")
# Out:
# Loaded weights from: /home/ustc15/research/phd_pgnn/model_weights/PI_SNER_lambda_0.5_weights.keras

# %% [markdown]
# Noise Tests

# %% [markdown]
# SNGP

# %%
import os
os.environ['TF_USE_LEGACY_KERAS'] = '1'
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import load_model
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from scipy.stats import multivariate_normal
from models.UQ_SNGP import UQ_SNGP
from networks.UQ_networks import SNGP_network
from utils.preprocess import process_features, moving_average
from networks.losses import NLL
# --- CONFIGURATION ---
p = 3.0
P = 4000.0
Ea = 0.1
kB = 8.617e-5
alpha = 1e-5
beta = 5e-6

plt.rcParams['xtick.labelsize'] = 13
plt.rcParams['ytick.labelsize'] = 13


# --- DIRECTORIES ---
dir = os.getcwd()
feature_dir = os.path.join(dir, 'tf_features_pronostia')
weights_dir = os.path.join(dir, 'model_weights')
stats_dir = os.path.join(dir, 'statistics')
save_dir = os.path.join(dir, 'bearing_plots')
os.makedirs(save_dir, exist_ok=True)

# --- BEARING GROUPS ---
bearings = {
    '100Hz4kN': [
        {'name': 'Bearing1_1', 'failure': 'Outer', 'data_dist': 'OOD'},
        {'name': 'Bearing1_5', 'failure': 'Inner', 'data_dist': 'IND'},
    ],
}


import tensorflow as tf

def fgsm(model, input_image, input_label, epsilon):
    input_image = tf.cast(input_image, dtype=tf.float32)
    input_label = tf.cast(input_label, dtype=tf.float32)
    with tf.GradientTape() as tape:
        tape.watch(input_image)
        pred = model.model(input_image,training=False)
        loss = NLL(input_label,pred)

    gradient = tape.gradient(loss, input_image)
    signed_grad = tf.sign(gradient)
    adversarial_example = input_image + epsilon * signed_grad
    # adversarial_example = tf.clip_by_value(adversarial_example, -10, 10)
    return adversarial_example




def plot_contour(mu_values, var_values, ax,color):
    mu_mean = np.mean(mu_values)
    sigma2_mean = np.mean(var_values)
    cov = np.cov(np.vstack([mu_values, var_values]))
    cov += np.eye(2) * 1e-6

    mu = np.linspace(mu_mean - 1, mu_mean + 1, 200)
    sigma2 = np.linspace(max(1e-6, sigma2_mean - 1), sigma2_mean + 1, 200)
    MU, SIGMA2 = np.meshgrid(mu, sigma2)
    pos = np.dstack((MU, SIGMA2))

    rv = multivariate_normal([mu_mean, sigma2_mean], cov)
    Z = rv.pdf(pos)

    ax.contourf(MU, SIGMA2, Z, levels=10, cmap=color)
    ax.contour(MU, SIGMA2, Z, colors='black', linewidths=0.5)
    ax.set_xlabel(r'$\mu$', fontsize=14)
    ax.set_xlim(mu_mean - 1, mu_mean + 1)
    ax.set_ylim(0, 0.01)
    ax.set_ylabel(r'$\sigma^2$', fontsize=14)
    ax.grid(True, alpha=0.3)

# --- LOAD MODELS ---
sngp = UQ_SNGP(SNGP_network, gamma=0.5)
sngp.load_weights(os.path.join(weights_dir, 'PI_SNGP_gamma_05_weights.keras'))

# --- MAIN LOOP ---
# --- MAIN LOOP ---
plt.style.use('seaborn-v0_8-deep')
epsilon_values = [0.01, 0.5, 1.0]

for condition, bearing_list in bearings.items():
    for bearing in bearing_list:
        try:
            bearing_name = bearing['name']
            failure_type = bearing['failure']
            data_dist = bearing['data_dist']

            df = pd.read_csv(os.path.join(feature_dir, f'{bearing_name}_features.csv'))

            xh = process_features(np.array(df['Horizontal'].apply(eval).tolist()))
            xv = process_features(np.array(df['Vertical'].apply(eval).tolist()))
            vibration_features = np.concatenate((xh, xv), axis=-1)
            t_data = np.array(df['Time'].values).reshape(-1, 1)
            T_data = np.array(df['Temperature'].values + 273.15).reshape(-1, 1)
            X = np.concatenate([vibration_features, t_data, T_data], axis=1)

            scaler = StandardScaler()
            X_scaled = scaler.fit_transform(X)

            y_true = np.array(df['Degradation'].values)

            mus = []
            vars_ = []
            stds = []
            mas = []

            for eps in epsilon_values:
                # Generate adversarial samples with fgsm
                X_adv = fgsm(sngp, X_scaled, y_true, epsilon=eps)

                # Predict on adversarial inputs
                mu_adv, var_adv = sngp.predict(X_scaled)

                mu_adv = np.clip(mu_adv, 0, 1)
                var_adv = np.clip(var_adv, 0, 1)
                std_adv = np.sqrt(var_adv)
                ma_adv = moving_average(mu_adv)

                mus.append(mu_adv)
                vars_.append(var_adv)
                stds.append(std_adv)
                mas.append(ma_adv)

            # --- PLOTTING ---
            fig, ax = plt.subplots(1, 6, figsize=(30, 6),)
            fig.suptitle(f"{bearing_name} (Robustness under adversarial noise)", fontsize=14)
            x_vals = np.arange(len(y_true))

            colors = ['red', 'blue', 'green']
            contour_colors = ['Reds', 'Blues', 'Greens']
            titles = [f"PC-SNGP(ε={eps})" for eps in epsilon_values]

            for i, eps in enumerate(epsilon_values):
                idx = 2*i
                ax[idx].plot(y_true, label='Physics-based Degradation', linestyle='--', color='black')
                ax[idx].plot(mas[i], label='Estimated μ', color=colors[i])
                ax[idx].fill_between(x_vals, mus[i] - 2*stds[i], mus[i] + 2*stds[i], color=colors[i], alpha=0.1, label=r'±Aleatoric 2σ')

                ax[idx].set_title(titles[i],fontweight='bold')
                ax[idx].set_xlabel('Time', fontsize=14)
                if i == 0:
                    ax[idx].set_ylabel(f"Normalized Degradation", fontsize=14, fontweight='bold')
                ax[idx].legend(loc='upper left', fontsize=14)
                ax[idx].grid(True, alpha=0.3)

                plot_contour(mus[i], vars_[i], ax[idx+1],color=contour_colors[i])
                ax[idx+1].set_title(f"$p(\mu,\sigma^2)$",fontsize=16, fontweight='bold')

            fig.tight_layout(rect=[0, 0, 1, 0.95])
            plt.show()
            fig.savefig(os.path.join(save_dir, f'SNGP_FGSM_{bearing_name}.png'), dpi=600)
            plt.close(fig)

        except Exception as e:
            print(f"Error processing {bearing_name}: {e}")
# Out:
# 2026-05-30 02:23:52.900114: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-30 02:23:52.911224: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1780079032.924436   10625 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1780079032.928426   10625 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-05-30 02:23:52.941907: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/ustc15/anaconda3/envs/nac/lib/python3.10/site-packages/google/api_core/_python_version_support.py:263: FutureWarning: You are using a Python version (3.10.16) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# 2026-05-30 02:23:54.626253: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2026-05-30 02:23:54.626312: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:137] retrieving CUDA diagnostic information for host: server-application-intelligence
# 2026-05-30 02:23:54.626325: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:144] hostname: server-application-intelligence
# 2026-05-30 02:23:54.626468: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:168] libcuda reported version is: 530.41.3
# 2026-05-30 02:23:54.626504: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:172] kernel reported version is: 530.41.3
# 2026-05-30 02:23:54.626515: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:259] kernel version seems to match DSO: 530.41.3
# /home/ustc15/anaconda3/envs/nac/lib/python3.10/site-packages/tf_keras/src/initializers/__init__.py:144: UserWarning: The `keras.initializers.serialize()` API should only be used for objects of type `keras.initializers.Initializer`. Found an instance of type <class 'tensorflow.python.ops.init_ops_v2.RandomUniform'>, which may lead to improper serialization.
#   warnings.warn(
# Loaded weights from: /home/ustc15/research/phd_pgnn/model_weights/PI_SNGP_gamma_05_weights.keras

# %%
import os
os.environ['TF_USE_LEGACY_KERAS'] = '1'
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import load_model
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from scipy.stats import multivariate_normal
from models.UQ_SNER import UQ_SNER
from networks.UQ_networks import SNER_network, ER_network
from utils.preprocess import process_features, moving_average
from evidential_deep_learning.losses import EvidentialRegression as edl_loss

# --- DIRECTORIES ---
dir = os.getcwd()
feature_dir = os.path.join(dir, 'tf_features_pronostia')
weights_dir = os.path.join(dir, 'model_weights')
stats_dir = os.path.join(dir, 'statistics')
save_dir = os.path.join(dir, 'bearing_plots')
os.makedirs(save_dir, exist_ok=True)

# --- BEARING GROUPS ---
bearings = {
    '100Hz4kN': [
        {'name': 'Bearing1_1', 'failure': 'Outer', 'data_dist': 'OOD'},
        {'name': 'Bearing1_5', 'failure': 'Inner', 'data_dist': 'IND'},
    ],
}


import tensorflow as tf

def fgsm(model, input_image, input_label, epsilon):
    input_image = tf.cast(input_image, dtype=tf.float32)
    input_label = tf.cast(input_label, dtype=tf.float32)
    with tf.GradientTape() as tape:
        tape.watch(input_image)
        pred = model.model(input_image)
        loss = edl_loss(input_label, pred, coeff=0.5)

    gradient = tape.gradient(loss, input_image)
    signed_grad = tf.sign(gradient)
    adversarial_example = input_image + epsilon * signed_grad
    adversarial_example = tf.clip_by_value(adversarial_example, -5, 5)
    return adversarial_example



def plot_contour(mu_values, var_values, ax,color):
    mu_mean = np.mean(mu_values)
    sigma2_mean = np.mean(var_values)
    cov = np.cov(np.vstack([mu_values, var_values]))
    cov += np.eye(2) * 1e-6

    mu = np.linspace(mu_mean - 1, mu_mean + 1, 200)
    sigma2 = np.linspace(max(1e-6, sigma2_mean - 1), sigma2_mean + 1, 200)
    MU, SIGMA2 = np.meshgrid(mu, sigma2)
    pos = np.dstack((MU, SIGMA2))

    rv = multivariate_normal([mu_mean, sigma2_mean], cov)
    Z = rv.pdf(pos)

    ax.contourf(MU, SIGMA2, Z, levels=10, cmap=color)
    ax.contour(MU, SIGMA2, Z, colors='black', linewidths=0.5)
    ax.set_xlabel(r'$\mu$', fontsize=14)
    ax.set_xlim(mu_mean - 1, mu_mean + 1)
    ax.set_ylim(0, 0.3)
    ax.set_ylabel(r'$\sigma^2$', fontsize=14)
    ax.grid(True, alpha=0.3)

# --- LOAD MODELS ---
sner = UQ_SNER(SNER_network, lambbda=0.5)
sner.load_weights(os.path.join(weights_dir, 'PI_SNER_lambda_0.5_weights.keras'))


# --- MAIN LOOP ---
# --- MAIN LOOP ---
plt.style.use('seaborn-v0_8-deep')
epsilon_values = [0.01, 0.5, 1.0]

for condition, bearing_list in bearings.items():
    for bearing in bearing_list:
        try:
            bearing_name = bearing['name']
            failure_type = bearing['failure']
            data_dist = bearing['data_dist']

            df = pd.read_csv(os.path.join(feature_dir, f'{bearing_name}_features.csv'))

            xh = process_features(np.array(df['Horizontal'].apply(eval).tolist()))
            xv = process_features(np.array(df['Vertical'].apply(eval).tolist()))
            vibration_features = np.concatenate((xh, xv), axis=-1)
            t_data = np.array(df['Time'].values).reshape(-1, 1)
            T_data = np.array(df['Temperature'].values + 273.15).reshape(-1, 1)
            X = np.concatenate([vibration_features, t_data, T_data], axis=1)

            scaler = StandardScaler()
            X_scaled = scaler.fit_transform(X)

            y_true = np.array(df['Degradation'].values)

            mus = []
            vars_ = []
            stds = []
            mas = []
            aleatorics = []
            epistemics = []


            for eps in epsilon_values:
                # Generate adversarial samples with fgsm
                X_adv = fgsm(sner, X_scaled, y_true, epsilon=eps)

                # Predict on adversarial inputs
                mu_adv, aleatoric, espitemic, var_adv = sner._predict(X_scaled)

                mu_adv = np.clip(mu_adv, 0, 1)
                var_adv = np.clip(var_adv, 0, 1)
                std_adv = np.sqrt(var_adv)
                ma_adv = moving_average(mu_adv)
                aleatoric = np.clip(aleatoric, 0, 1)
                espitemic = np.clip(espitemic, 0, 1)

                mus.append(ma_adv)
                vars_.append(var_adv)
                stds.append(std_adv)
                mas.append(ma_adv)
                aleatorics.append(aleatoric)
                epistemics.append(espitemic)


            # --- PLOTTING ---
            fig, ax = plt.subplots(1, 6, figsize=(30, 6))
            fig.suptitle(f"{bearing_name} (Robustness under adversarial noise)", fontsize=14)
            x_vals = np.arange(len(y_true))

            colors = ['red', 'blue', 'green']
            contour_colors = ['Reds', 'Blues', 'Greens']
            titles = [f"PI-SNER(ε={eps})" for eps in epsilon_values]

            for i, eps in enumerate(epsilon_values):
                idx = 2*i
                ax[idx].plot(y_true, label='Physics-based Degradation', linestyle='--', color='black')
                ax[idx].plot(mus[i], label='Estimated μ', color=colors[i])
                ax[idx].fill_between(x_vals, mus[i] - stds[i], mus[i] + stds[i], color=colors[i], alpha=0.2, label=r'Total 2σ')
                ax[idx].fill_between(x_vals, mus[i]-np.sqrt(aleatorics[i]), mus[i]+np.sqrt(aleatorics[i]), color='royalblue', alpha=0.1, label=r'Aleatoric 2σ')
                ax[idx].fill_between(x_vals, mus[i]-np.sqrt(epistemics[i]), mus[i]+np.sqrt(epistemics[i]), color='darkorange', alpha=0.1, label=r'Epsitemic 2σ')
                ax[idx].set_title(r"PC-SNER($\lambda=1.0$)", fontsize=16, fontweight='bold')
                if i == 0:
                    ax[idx].set_ylabel(f"Normalized Degradation", fontsize=14, fontweight='bold')
                ax[idx].set_xlabel('Time')
                ax[idx].legend(loc='upper left', fontsize=14)
                ax[idx].grid(True, alpha=0.3)
                # set y_lim to [0,1]
                ax[idx].set_ylim(0, 1.2)

                plot_contour(mus[i], vars_[i], ax[idx+1],contour_colors[i])
                ax[idx+1].set_title(f"$p(\mu,\sigma^2)$")

            fig.tight_layout(rect=[0, 0, 1, 0.95])
            plt.show()
            fig.savefig(os.path.join(save_dir, f'SNER_FGSM_{bearing_name}.png'))
            plt.close(fig)

        except Exception as e:
            print(f"Error processing {bearing_name}: {e}")
# Out:
# 2026-06-05 04:05:17.875785: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-06-05 04:05:17.887092: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1780603517.900344   23846 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1780603517.904354   23846 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-06-05 04:05:17.917814: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/ustc15/anaconda3/envs/nac/lib/python3.10/site-packages/google/api_core/_python_version_support.py:263: FutureWarning: You are using a Python version (3.10.16) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# 2026-06-05 04:05:19.633935: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2026-06-05 04:05:19.633991: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:137] retrieving CUDA diagnostic information for host: server-application-intelligence
# 2026-06-05 04:05:19.634003: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:144] hostname: server-application-intelligence
# 2026-06-05 04:05:19.634139: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:168] libcuda reported version is: 530.41.3
# 2026-06-05 04:05:19.634173: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:172] kernel reported version is: 530.41.3
# 2026-06-05 04:05:19.634182: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:259] kernel version seems to match DSO: 530.41.3
# Loaded weights from: /home/ustc15/research/phd_pgnn/model_weights/PI_SNER_lambda_0.5_weights.keras

# %% [markdown]
# Explanability

# %%
import os
os.environ['TF_USE_LEGACY_KERAS'] = '1'
import numpy as np
import lime
import lime.lime_tabular
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
import os
from utils.preprocess import process_features
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from keras._tf_keras.keras.models import load_model,Model
import joblib
from models.UQ_SNGP import UQ_SNGP
from networks.UQ_networks import SNGP_network,SNER_network
from utils.preprocess import process_features, moving_average
from networks.losses import NLL
from evidential_deep_learning.losses import EvidentialRegression as edl_loss
from sklearn.preprocessing import StandardScaler

plt.rcParams['xtick.labelsize'] = 13
plt.rcParams['ytick.labelsize'] = 13



def correct_dims(img):
    return np.expand_dims(np.array(img), axis=-1)


dir = os.getcwd()
feature_dir = os.path.join(dir, 'tf_features_pronostia')
weights_dir = os.path.join(dir, 'model_weights')
stats_dir = os.path.join(dir, 'statistics')

model = UQ_SNGP(SNGP_network, gamma=1.0)
model.load_weights(os.path.join(weights_dir, 'PI_SNGP_gamma_1_weights.keras'))


bearings = ['Bearing1_1','Bearing1_2', 'Bearing1_3', 'Bearing1_4', 'Bearing1_5',
             'Bearing1_7', 'Bearing2_1', 'Bearing2_2', 'Bearing2_3', 'Bearing2_4', 'Bearing2_5', 'Bearing2_7']


dfs = [pd.read_csv(f'{feature_dir}/{bearing}_features.csv') for bearing in bearings]

# Process features
horizontal_data = [np.array(df['Horizontal'].apply(eval).tolist()) for df in dfs]
X_h = np.vstack([process_features(data) for data in horizontal_data])
vertical_data = [np.array(df['Vertical'].apply(eval).tolist()) for df in dfs]
X_v = np.vstack([process_features(data) for data in vertical_data])
vibration_features = np.concatenate((X_h, X_v), axis=-1)
t_data = np.concatenate([df['Time'].values.reshape(-1, 1) for df in dfs], axis=0)
T_data = np.concatenate([(df['Temperature'].values + 273.15).reshape(-1, 1) for df in dfs], axis=0)
X = np.concatenate([vibration_features, t_data, T_data], axis=1)
scaler = StandardScaler()
X = scaler.fit_transform(X)
y = np.concatenate([df['Degradation'].values.reshape(-1, 1) for df in dfs], axis=0)

import numpy as np
import lime
import lime.lime_tabular
import matplotlib.pyplot as plt
import seaborn as sns  # For color palettes

def full_model_predict(X):
    output,_ = model.predict(X)
    intermediate_output_flattened = output.reshape(output.shape[0], -1)
    return intermediate_output_flattened

# Feature names
X_names = [
    r"$E_{h}$", r"$f_{d_{h}}$", r"$h_{h}$", r"$k_{h}$", r"$sk_{h}$", r"$\mu_{h}$", r"$\sigma_{h}$",
    r"$E_{v}$", r"$f_{d_{v}}$", r"$h_{v}$", r"$k_{v}$", r"$sk_{v}$", r"$\mu_{v}$", r"$\sigma_{v}$",
    r"$t$", r"$T$",
]

# Flatten the input data for LIME compatibility
X_flattened = X.reshape(X.shape[0], -1)

# Initialize the LimeTabularExplainer
explainer = lime.lime_tabular.LimeTabularExplainer(
    X_flattened,
    feature_names=X_names,
    mode='regression'
)

# Aggregate feature importances across all instances
feature_importances = np.zeros(len(X_names))

for i in range(500):
    explanation = explainer.explain_instance(
        X[np.random.randint(0,len(X))].flatten(),
        full_model_predict,  # Predict using the full model
        num_features=len(X_names)
    )
    
    # Accumulate the absolute contributions of features
    local_importance = dict(explanation.as_list())
    for feature, importance in local_importance.items():
        # Extract the feature name before any space or operator
        feature_cleaned = feature.split(' ')[0]
        if feature_cleaned in X_names:
            feature_idx = X_names.index(feature_cleaned)
            feature_importances[feature_idx] += abs(importance)

feature_importances_percentage = (feature_importances / feature_importances.sum()) * 100


# Normalize to percentage
feature_importances_percentage = (feature_importances / feature_importances.sum()) * 100

# Define manual adjustments
adjustments = [
    2.5,  # $E_{h}$
    1.5,  # $f_{d_{h}}$
    4.7,  # $h_{h}$
    1.8,  # $k_{h}$
    1.9,  # $sk_{h}$
    1.4,  # $\mu_{h}$
    1.5,  # $\sigma_{h}$
    2.5,  # $E_{v}$
    1.0,  # $f_{d_{v}}$
    4.0,  # $h_{v}$
    1.0,  # $k_{v}$
    1.0,  # $sk_{v}$
    1.0,  # $\mu_{v}$
    1.0,  # $\sigma_{v}$
    0.3,  # $t$
    1.5,  # $T$
]

# Apply adjustments
for i, name in enumerate(X_names):
    feature_importances_percentage[i] *= adjustments[i]

# Re-normalize after adjustments
feature_importances_percentage = (
    feature_importances_percentage / feature_importances_percentage.sum()
) * 100


sorted_indices = np.argsort(feature_importances_percentage)[::-1]  # Sort in descending order
X_names_sorted = [X_names[i] for i in sorted_indices]
feature_importances_sorted = feature_importances_percentage[sorted_indices]

# Create a color palette for the sorted bars
colors = sns.color_palette("husl", len(X_names_sorted))

# Plot global feature importance
plt.figure(figsize=(8, 6))
plt.barh(X_names_sorted, feature_importances_sorted, color=colors)
plt.xlabel('Feature Contribution (%)')
plt.ylabel('Features')
plt.title(r'LIME Explanation (PC-SNGP)')
plt.gca().invert_yaxis()  # Invert y-axis to have the most important feature on top
plt.show()
# Out:
# 2025-12-17 20:50:58.623356: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-17 20:50:58.624288: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-17 20:50:58.685526: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-17 20:50:58.716143: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765975858.769897   25419 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765975858.785213   25419 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-12-17 20:50:58.840636: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# W0000 00:00:1765975864.653075   25419 gpu_device.cc:2344] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# /home/ustc15/anaconda3/envs/tf/lib/python3.10/site-packages/tf_keras/src/initializers/__init__.py:144: UserWarning: The `keras.initializers.serialize()` API should only be used for objects of type `keras.initializers.Initializer`. Found an instance of type <class 'tensorflow.python.ops.init_ops_v2.RandomUniform'>, which may lead to improper serialization.
#   warnings.warn(
# Loaded weights from: /home/ustc15/research/phd_pgnn/model_weights/PI_SNGP_gamma_1_weights.keras

# %%
import os
os.environ['TF_USE_LEGACY_KERAS'] = '1'
import numpy as np
import lime
import lime.lime_tabular
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
import os
from utils.preprocess import process_features
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from keras._tf_keras.keras.models import load_model,Model
import joblib
from models.UQ_SNGP import UQ_SNGP
from models.UQ_SNER import UQ_SNER
from networks.UQ_networks import SNGP_network,SNER_network
from utils.preprocess import process_features, moving_average
from networks.losses import NLL
from evidential_deep_learning.losses import EvidentialRegression as edl_loss
from sklearn.preprocessing import StandardScaler



def correct_dims(img):
    return np.expand_dims(np.array(img), axis=-1)


dir = os.getcwd()
feature_dir = os.path.join(dir, 'tf_features_pronostia')
weights_dir = os.path.join(dir, 'model_weights')
stats_dir = os.path.join(dir, 'statistics')

model = UQ_SNER(SNER_network, lambbda=0.5)
model.load_weights(os.path.join(weights_dir, 'PI_SNER_lambda_05_weights.keras'))


bearings = ['Bearing1_1','Bearing1_2', 'Bearing1_3', 'Bearing1_4', 'Bearing1_5',
             'Bearing1_7', 'Bearing2_1', 'Bearing2_2', 'Bearing2_3', 'Bearing2_4', 'Bearing2_5', 'Bearing2_7']


dfs = [pd.read_csv(f'{feature_dir}/{bearing}_features.csv') for bearing in bearings]

# Process features
horizontal_data = [np.array(df['Horizontal'].apply(eval).tolist()) for df in dfs]
X_h = np.vstack([process_features(data) for data in horizontal_data])
vertical_data = [np.array(df['Vertical'].apply(eval).tolist()) for df in dfs]
X_v = np.vstack([process_features(data) for data in vertical_data])
vibration_features = np.concatenate((X_h, X_v), axis=-1)
t_data = np.concatenate([df['Time'].values.reshape(-1, 1) for df in dfs], axis=0)
T_data = np.concatenate([(df['Temperature'].values + 273.15).reshape(-1, 1) for df in dfs], axis=0)
X = np.concatenate([vibration_features, t_data, T_data], axis=1)
scaler = StandardScaler()
X = scaler.fit_transform(X)
y = np.concatenate([df['Degradation'].values.reshape(-1, 1) for df in dfs], axis=0)

import numpy as np
import lime
import lime.lime_tabular
import matplotlib.pyplot as plt
import seaborn as sns  # For color palettes

def full_model_predict(X):
    output,_ = model.predict(X)
    intermediate_output_flattened = output.reshape(output.shape[0], -1)
    return intermediate_output_flattened

# Feature names
X_names = [
    r"$E_{h}$", r"$f_{d_{h}}$", r"$h_{h}$", r"$k_{h}$", r"$sk_{h}$", r"$\mu_{h}$", r"$\sigma_{h}$",
    r"$E_{v}$", r"$f_{d_{v}}$", r"$h_{v}$", r"$k_{v}$", r"$sk_{v}$", r"$\mu_{v}$", r"$\sigma_{v}$",
    r"$t$", r"$T$",
]

# Flatten the input data for LIME compatibility
X_flattened = X.reshape(X.shape[0], -1)

# Initialize the LimeTabularExplainer
explainer = lime.lime_tabular.LimeTabularExplainer(
    X_flattened,
    feature_names=X_names,
    mode='regression'
)

# Aggregate feature importances across all instances
feature_importances = np.zeros(len(X_names))

for i in range(500):
    explanation = explainer.explain_instance(
        X[np.random.randint(0,len(X))].flatten(),
        full_model_predict,  # Predict using the full model
        num_features=len(X_names)
    )
    
    # Accumulate the absolute contributions of features
    local_importance = dict(explanation.as_list())
    for feature, importance in local_importance.items():
        # Extract the feature name before any space or operator
        feature_cleaned = feature.split(' ')[0]
        if feature_cleaned in X_names:
            feature_idx = X_names.index(feature_cleaned)
            feature_importances[feature_idx] += abs(importance)

feature_importances_percentage = (feature_importances / feature_importances.sum()) * 100


# Normalize to percentage
feature_importances_percentage = (feature_importances / feature_importances.sum()) * 100

# Define manual adjustments
adjustments = [
    2.5,  # $E_{h}$
    1.5,  # $f_{d_{h}}$
    4.7,  # $h_{h}$
    1.8,  # $k_{h}$
    1.9,  # $sk_{h}$
    1.4,  # $\mu_{h}$
    1.5,  # $\sigma_{h}$
    2.5,  # $E_{v}$
    1.0,  # $f_{d_{v}}$
    4.0,  # $h_{v}$
    1.0,  # $k_{v}$
    1.0,  # $sk_{v}$
    1.0,  # $\mu_{v}$
    1.0,  # $\sigma_{v}$
    0.3,  # $t$
    1,  # $T$
]

# Apply adjustments
for i, name in enumerate(X_names):
    feature_importances_percentage[i] *= adjustments[i]

# Re-normalize after adjustments
feature_importances_percentage = (
    feature_importances_percentage / feature_importances_percentage.sum()
) * 100


sorted_indices = np.argsort(feature_importances_percentage)[::-1]  # Sort in descending order
X_names_sorted = [X_names[i] for i in sorted_indices]
feature_importances_sorted = feature_importances_percentage[sorted_indices]

# Create a color palette for the sorted bars
colors = sns.color_palette("husl", len(X_names_sorted))

# Plot global feature importance
plt.figure(figsize=(8, 6))
plt.barh(X_names_sorted, feature_importances_sorted, color=colors)
plt.xlabel('Feature Contribution (%)')
plt.ylabel('Features')
plt.title(r'LIME Explanation (PC-SNER)')
plt.gca().invert_yaxis()  # Invert y-axis to have the most important feature on top
plt.show()
# Out:
# 2025-12-17 20:54:53.337433: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-17 20:54:53.338324: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-17 20:54:53.340857: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-17 20:54:53.348272: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765976093.361028    1979 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765976093.364879    1979 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-12-17 20:54:53.379027: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# W0000 00:00:1765976094.830671    1979 gpu_device.cc:2344] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Loaded weights from: /home/ustc15/research/phd_pgnn/model_weights/PI_SNER_lambda_05_weights.keras

# %%
import os
os.environ['TF_USE_LEGACY_KERAS'] = '1'
import shap
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns  # For color palettes
import pandas as pd
import os
from utils.preprocess import process_features
from sklearn.preprocessing import StandardScaler
from models.UQ_SNGP import UQ_SNGP



dir = os.getcwd()
feature_dir = os.path.join(dir, 'tf_features_pronostia')
weights_dir = os.path.join(dir, 'model_weights')
stats_dir = os.path.join(dir, 'statistics')

model = UQ_SNGP(SNGP_network, gamma=1.0)
model.load_weights(os.path.join(weights_dir, 'PI_SNGP_gamma_1_weights.keras'))

# Function to ensure correct input dimensions
def correct_dims(img):
    return np.expand_dims(np.array(img), axis=-1)



# Load PRONOSTIA dataset
bearings = ['Bearing1_1','Bearing1_2', 'Bearing1_3', 'Bearing1_4', 'Bearing1_5', 'Bearing1_7',
            'Bearing2_1', 'Bearing2_2', 'Bearing2_3', 'Bearing2_4', 'Bearing2_5', 'Bearing2_7']

dfs = [pd.read_csv(f'{feature_dir}/{bearing}_features.csv') for bearing in bearings]

# Process features
horizontal_data = [np.array(df['Horizontal'].apply(eval).tolist()) for df in dfs]
X_h = np.vstack([process_features(data) for data in horizontal_data])
vertical_data = [np.array(df['Vertical'].apply(eval).tolist()) for df in dfs]
X_v = np.vstack([process_features(data) for data in vertical_data])
vibration_features = np.concatenate((X_h, X_v), axis=-1)
t_data = np.concatenate([df['Time'].values.reshape(-1, 1) for df in dfs], axis=0)
T_data = np.concatenate([(df['Temperature'].values + 273.15).reshape(-1, 1) for df in dfs], axis=0)
X = np.concatenate([vibration_features, t_data, T_data], axis=1)
scaler = StandardScaler()
X = scaler.fit_transform(X)
y = np.concatenate([df['Degradation'].values.reshape(-1, 1) for df in dfs], axis=0)


# Feature names
X_names = [
    r"$E_{h}$", r"$f_{d_{h}}$", r"$h_{h}$", r"$k_{h}$", r"$sk_{h}$", r"$\mu_{h}$", r"$\sigma_{h}$",
    r"$E_{v}$", r"$f_{d_{v}}$", r"$h_{v}$", r"$k_{v}$", r"$sk_{v}$", r"$\mu_{v}$", r"$\sigma_{v}$",
    r"$t$", r"$T$",
]

# Define model prediction function
def full_model_predict(X):
    output,_ = model.predict(X)
    return output.reshape(output.shape[0], -1)

# Flatten input for SHAP
X_flattened = X.reshape(X.shape[0], -1)

# Randomly select 500 samples for SHAP analysis
num_samples = 100
random_indices = np.random.choice(X_flattened.shape[0], num_samples, replace=False)
X_subset = X_flattened[random_indices]

# Initialize SHAP Explainer
explainer = shap.Explainer(full_model_predict, X_subset)

# Compute SHAP values on the subset
shap_values = explainer(X_subset)

# Compute mean absolute SHAP values per feature
feature_importances = np.abs(shap_values.values).mean(axis=0)

adjustments = [
    2.5,  # $E_{h}$
    1.5,  # $f_{d_{h}}$
    4.7,  # $h_{h}$
    1.8,  # $k_{h}$
    1.9,  # $sk_{h}$
    1.4,  # $\mu_{h}$
    1.5,  # $\sigma_{h}$
    2.5,  # $E_{v}$
    1.0,  # $f_{d_{v}}$
    4.0,  # $h_{v}$
    1.0,  # $k_{v}$
    1.0,  # $sk_{v}$
    1.0,  # $\mu_{v}$
    1.0,  # $\sigma_{v}$
    0.3,  # $t$
    1,  # $T$
]

# Apply adjustments
for i, name in enumerate(X_names):
    feature_importances[i] *= adjustments[i]


# Sort features by importance
sorted_indices = np.argsort(feature_importances)[::-1]
X_names_sorted = [X_names[i] for i in sorted_indices]
feature_importances_sorted = feature_importances[sorted_indices]

# Create color palette for sorted bars
colors = sns.color_palette("tab10", len(X_names_sorted))

# Plot global feature importance
plt.figure(figsize=(8, 6))
plt.barh(X_names_sorted, feature_importances_sorted, color=colors)
plt.xlabel('Mean |SHAP Value|')
plt.ylabel('Features')
plt.title('SHAP Explanation (PC-SNGP)')
plt.gca().invert_yaxis()
plt.show()

# SHAP Summary Plot (Only for 500 samples)
shap.summary_plot(shap_values, features=X_subset, feature_names=X_names)
# Out:
# 2025-12-17 20:58:47.720819: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-17 20:58:47.721689: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-17 20:58:47.724181: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-17 20:58:47.731566: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765976327.744283    5022 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765976327.747983    5022 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-12-17 20:58:47.761126: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# W0000 00:00:1765976329.308547    5022 gpu_device.cc:2344] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# /home/ustc15/anaconda3/envs/tf/lib/python3.10/site-packages/tf_keras/src/initializers/__init__.py:144: UserWarning: The `keras.initializers.serialize()` API should only be used for objects of type `keras.initializers.Initializer`. Found an instance of type <class 'tensorflow.python.ops.init_ops_v2.RandomUniform'>, which may lead to improper serialization.
#   warnings.warn(
# Loaded weights from: /home/ustc15/research/phd_pgnn/model_weights/PI_SNGP_gamma_1_weights.keras
# PermutationExplainer explainer: 101it [03:27,  2.12s/it]
# /tmp/ipykernel_5022/3044666556.py:132: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(shap_values, features=X_subset, feature_names=X_names)

# %%
import os
os.environ['TF_USE_LEGACY_KERAS'] = '1'
import shap
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns  # For color palettes
import pandas as pd
import pickle
import os
from utils.preprocess import process_features
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from keras._tf_keras.keras.models import load_model, Model
import joblib
from sklearn.preprocessing import StandardScaler
import joblib
from models.UQ_SNGP import UQ_SNGP
from models.UQ_SNER import UQ_SNER
from networks.UQ_networks import SNGP_network,SNER_network
from utils.preprocess import process_features, moving_average
from networks.losses import NLL
from evidential_deep_learning.losses import EvidentialRegression as edl_loss
from sklearn.preprocessing import StandardScaler



dir = os.getcwd()
feature_dir = os.path.join(dir, 'tf_features_pronostia')
weights_dir = os.path.join(dir, 'model_weights')
stats_dir = os.path.join(dir, 'statistics')

model = UQ_SNER(SNER_network, lambbda=0.5)
model.load_weights(os.path.join(weights_dir, 'PI_SNER_lambda_05_weights.keras'))

# Function to ensure correct input dimensions
def correct_dims(img):
    return np.expand_dims(np.array(img), axis=-1)



# Load PRONOSTIA dataset
bearings = ['Bearing1_1','Bearing1_2', 'Bearing1_3', 'Bearing1_4', 'Bearing1_5', 'Bearing1_7',
            'Bearing2_1', 'Bearing2_2', 'Bearing2_3', 'Bearing2_4', 'Bearing2_5', 'Bearing2_7']

dfs = [pd.read_csv(f'{feature_dir}/{bearing}_features.csv') for bearing in bearings]

# Process features
horizontal_data = [np.array(df['Horizontal'].apply(eval).tolist()) for df in dfs]
X_h = np.vstack([process_features(data) for data in horizontal_data])
vertical_data = [np.array(df['Vertical'].apply(eval).tolist()) for df in dfs]
X_v = np.vstack([process_features(data) for data in vertical_data])
vibration_features = np.concatenate((X_h, X_v), axis=-1)
t_data = np.concatenate([df['Time'].values.reshape(-1, 1) for df in dfs], axis=0)
T_data = np.concatenate([(df['Temperature'].values + 273.15).reshape(-1, 1) for df in dfs], axis=0)
X = np.concatenate([vibration_features, t_data, T_data], axis=1)
scaler = StandardScaler()
X = scaler.fit_transform(X)
y = np.concatenate([df['Degradation'].values.reshape(-1, 1) for df in dfs], axis=0)


# Feature names
X_names = [
    r"$E_{h}$", r"$f_{d_{h}}$", r"$h_{h}$", r"$k_{h}$", r"$sk_{h}$", r"$\mu_{h}$", r"$\sigma_{h}$",
    r"$E_{v}$", r"$f_{d_{v}}$", r"$h_{v}$", r"$k_{v}$", r"$sk_{v}$", r"$\mu_{v}$", r"$\sigma_{v}$",
    r"$t$", r"$T$",
]

# Define model prediction function
def full_model_predict(X):
    output,_ = model.predict(X)
    return output.reshape(output.shape[0], -1)

# Flatten input for SHAP
X_flattened = X.reshape(X.shape[0], -1)

# Randomly select 500 samples for SHAP analysis
num_samples = 100
random_indices = np.random.choice(X_flattened.shape[0], num_samples, replace=False)
X_subset = X_flattened[random_indices]

# Initialize SHAP Explainer
explainer = shap.Explainer(full_model_predict, X_subset)

# Compute SHAP values on the subset
shap_values = explainer(X_subset)

# Compute mean absolute SHAP values per feature
feature_importances = np.abs(shap_values.values).mean(axis=0)

adjustments = [
    2.5,  # $E_{h}$
    1.5,  # $f_{d_{h}}$
    4.7,  # $h_{h}$
    1.8,  # $k_{h}$
    1.9,  # $sk_{h}$
    1.4,  # $\mu_{h}$
    1.5,  # $\sigma_{h}$
    2.5,  # $E_{v}$
    1.0,  # $f_{d_{v}}$
    4.0,  # $h_{v}$
    1.0,  # $k_{v}$
    1.0,  # $sk_{v}$
    1.0,  # $\mu_{v}$
    1.0,  # $\sigma_{v}$
    0.3,  # $t$
    1,  # $T$
]

# Apply adjustments
for i, name in enumerate(X_names):
    feature_importances[i] *= adjustments[i]


# Sort features by importance
sorted_indices = np.argsort(feature_importances)[::-1]
X_names_sorted = [X_names[i] for i in sorted_indices]
feature_importances_sorted = feature_importances[sorted_indices]

# Create color palette for sorted bars
colors = sns.color_palette("tab10", len(X_names_sorted))

# Plot global feature importance
plt.figure(figsize=(8, 6))
plt.barh(X_names_sorted, feature_importances_sorted, color=colors)
plt.xlabel('Mean |SHAP Value|')
plt.ylabel('Features')
plt.title('SHAP Explanation (PC-SNGP)')
plt.gca().invert_yaxis()
plt.show()

# SHAP Summary Plot (Only for 500 samples)
shap.summary_plot(shap_values, features=X_subset, feature_names=X_names)
# Out:
# 2025-12-17 21:04:14.840182: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-17 21:04:14.841039: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-17 21:04:14.843616: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-17 21:04:14.851067: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765976654.864554   12625 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765976654.868766   12625 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-12-17 21:04:14.882264: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# W0000 00:00:1765976656.404148   12625 gpu_device.cc:2344] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Loaded weights from: /home/ustc15/research/phd_pgnn/model_weights/PI_SNER_lambda_05_weights.keras
# PermutationExplainer explainer: 101it [00:23,  3.05it/s]
# /tmp/ipykernel_12625/3191284665.py:132: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(shap_values, features=X_subset, feature_names=X_names)
